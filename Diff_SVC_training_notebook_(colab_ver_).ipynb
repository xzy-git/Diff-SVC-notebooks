# %% [markdown]
# <a href="https://colab.research.google.com/github/haru0l/Diff-SVC-notebooks/blob/main/Diff_SVC_training_notebook_(colab_ver_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Training notebook for [Diff-SVC](https://github.com/prophesier/diff-svc) written by [Nekro](https://twitter.com/NekroTheCorpse) of [Archivoice](https://github.com/archivoice)
#
# Beta 44.1kHz version for training

# %% [markdown]
# # Check Setup

# %%
#@title #Check GPU type
#@markdown this is for checking the GPU type you have as well as the available amount of vram.
# !nvidia-smi -L
# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-5141226b-4acd-5384-ec17-4642c9ef1c89)
# Fri Mar 24 05:54:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title #Mount Google Drive

#@markdown Makes your life easier when uploading and saving stuff.

from google.colab import drive
drive.flush_and_unmount()
# !rm -rf /content/drive
drive.mount('/content/drive')
print('Done!')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive
# Done!

# %% [markdown]
# # Preparation

# %%
#@title #Step 1: Install Diff-SVC
#@markdown The stuff you'll need for every other thing afterwards.
from IPython.display import clear_output
import os
print('Upgrading pip & installing 7zip')
# !rm -rf /content/sample_data
# !python -m pip install --upgrade pip wheel
# !apt-get install unzip
# !pip uninstall gdown -y
# !pip install git+https://github.com/justinjohn0306/gdown.git

#print('Installing torch')
#%pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !pip install --pre torchtext==0.6.0 --no-deps

print('Installing Aria2')
# !apt install wget curl ca-certificates &> /dev/null
# !wget -N git.io/aria2.sh &> /dev/null && chmod +x aria2.sh &> /dev/null
# !echo 1|./aria2.sh &> /dev/null
# !echo 12|./aria2.sh &> /dev/null
# !echo 6|./aria2.sh &> /dev/null

#@markdown ---
#@markdown ###Select which fork to use
#@markdown The official repo is up-to-date, while UtaUtaUtau's version has Harvest support for improved f0.
fork = 'Self Repo' #@param ["Official Diff-SVC Repo", "UtaUtaUtau's Repo", "Self Repo"]

#@markdown ---
#@markdown ###Model sample rate
#@markdown Please choose if you want to train a 24kHz model or a 44.1kHz model.
sample_rate = '44.1kHz' #@param ["24kHz", "44.1kHz"]

print('Installing Diff-SVC')
if fork == "Official Diff-SVC Repo":
  # !git clone https://github.com/prophesier/diff-svc
elif fork == "UtaUtaUtau's Repo":
  # !pip install --upgrade numpy==1.23.0 scipy==1.9.3
  # !git clone --branch harvest-preprocess https://github.com/UtaUtaUtau/diff-svc
else:
  # !git clone https://github.com/xzy-git/diff-svc

# %cd "/content/diff-svc/"
# !pip install -r requirements_short.txt
# !pip install tensorboard<2.9,>=2.8
# !pip install numpy==1.23.5
# %reload_ext tensorboard

#@markdown ###Get Hubert & Hifgan Model(The link is dead. Upload them to your drive)
path = '/content/drive/MyDrive/diff-svc/checkpoints/' #@param {type:"string"}

# %cd "/content/diff-svc/training/"
# !rm config.yaml
# !wget https://github.com/haru0l/Diff-SVC-notebooks/releases/download/checkpoints/config.yaml -O config.yaml -q --show-progress
# %cd "/content/"
# !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/" https://github.com/haru0l/Diff-SVC-notebooks/releases/download/basic/checkpoints.zip -q
# !unzip /content/checkpoints.zip -d /content/diff-svc/

if sample_rate == "44.1kHz":
  config_path = "/content/diff-svc/training/config_nsf.yaml"
  # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/" https://github.com/justinjohn0306/diff-svc/releases/download/models/nsf_hifigan.zip -q
  # !unzip /content/nsf_hifigan.zip -d /content/diff-svc/checkpoints/
else:
  config_path = "/content/diff-svc/training/config.yaml"
  # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/" https://github.com/haru0l/Diff-SVC-notebooks/releases/download/models/hifigan.zip -q
  # !unzip /content/hifigan.zip -d /content/diff-svc/

import shutil
shutil.copytree(path,'/content/diff-svc/checkpoints/')

clear_output()
print('Done!')
# Out:
# Done!

# %%
#@title #Step 2: Decompress dataset
#@markdown This should work with most common archive formats, so don't worry. Please stick with the alphabet characters otherwise preprocessing might error out.

#@markdown Supported types: `.rar`, `.zip`, `.tar`, `.tar.gz`, `.tar.bz2`, `.7z`

#@markdown ###Note that your dataset should consist of `.wav` or `.ogg` format audio
#@markdown ---
#@markdown Name your singer.
singer_name = 'Altoria' #@param {type: "string"}
singer_name = singer_name.replace(" ", "_")
# %cd "/content/"

if sample_rate == "44.1kHz":
  # !sed -i -r 's/nyaru/{singer_name}/g' {config_path}
else:
  # !sed -i -r 's/atri/{singer_name}/g' {config_path}
  
#@markdown ---
#@markdown File location
# !mkdir -p /content/diff-svc/data/raw
dataset_location = '/content/drive/MyDrive/dataset_raw/Altoria.zip' #@param {type: "string"}
diffsvc_location = os.path.join('diff-svc', 'data', 'raw', singer_name, "")

if dataset_location.endswith('.rar'):
    # !unrar x "$dataset_location" "$diffsvc_location"
elif dataset_location.endswith('.zip'):
    # !unzip "$dataset_location" -d "$diffsvc_location"
elif dataset_location.endswith('.tar'):
    # !tar -xf "$dataset_location" -C "$diffsvc_location"
elif dataset_location.endswith('.tar.gz'):
    # !tar -xzf "$dataset_location" -C "$diffsvc_location"
elif dataset_location.endswith('.tar.bz2'):
    # !tar -xjf "$dataset_location" -C "$diffsvc_location"
else:
    !7za x "$dataset_location" -o$diffsvc_location

clear_output()
print('Done!')
# Out:
# Done!

# %%
#@title #Step 2-A: Decompress training data
#@markdown Decompresses training data directly to `diff-svc/data/binary`, usable only if you already have the output files of Step 4.

#@markdown If you run this step, please skip step 4.

#@markdown Supported types: check above. 

#@markdown ###You must match the training settings of the config.yaml file you used to generated the preprocessed data.
#@markdown ---
#@markdown Name your singer.
singer_name = 'Altoria' #@param {type: "string"}
singer_name = singer_name.replace(" ", "_")

if sample_rate == "44.1kHz":
  # !sed -i -r 's/nyaru/{singer_name}/g' {config_path}
else:
  # !sed -i -r 's/atri/{singer_name}/g' {config_path}

#@markdown ---
#@markdown File location
# !mkdir -p /content/diff-svc/data/binary
preprocessed_data_location = '/content/drive/MyDrive/diff-svc/data/Altoria/Altoria_binary_data.7z' #@param {type: "string"}
#@markdown So turns out this is important after all so yeah! It should be in the folder with your binary data.
config_location = '/content/drive/MyDrive/diff-svc/data/Altoria/config_nsf.yaml' #@param {type: "string"}
diffsvc_bin_location = '/content/diff-svc/data'

if preprocessed_data_location.endswith('.rar'):
    # !unrar x "$preprocessed_data_location" "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.zip'):
    # !unzip "$preprocessed_data_location" -d "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar'):
    # !tar -xf "$preprocessed_data_location" -C "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar.gz'):
    # !tar -xzf "$preprocessed_data_location" -C "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar.bz2'):
    # !tar -xjf "$preprocessed_data_location" -C "$diffsvc_bin_location"
else:
    !7za x "$preprocessed_data_location" -o$diffsvc_bin_location

if sample_rate == "44.1kHz":
  # !cp -r {config_location} /content/diff-svc/training
  
clear_output()
print('Done!')
# Out:
# Done!

# %% [markdown]
# # Training Preperations/Options/Parameters
# Unfortunately, you can not get away with no editing, not completely that is.

# %%
#@title #Step 3: Edit training parameters

K_step = 1000

batch_size = 12
if sample_rate == "44.1kHz":
  decay_steps = 20000
else:
  decay_steps = 60000

lr = '0.0008'

#@markdown ###F0 extraction method
#@markdown Crepe is used for F0 extraction for data preprocessing, while it is of higher quality, it is slow, therefore set to false as default.

#@markdown Unchecking this while using the official repo will default to parselmouth, while using UtaUtaUtau's repo will use harvest.
use_crepe = True #@param {type: "boolean"}

#@markdown ---
#@markdown ###Set checkpoint interval
#@markdown As the name states, saves a checkpoint at an interval. When using GPU training, it runs quite fast, so try not to touch this, there's no point.
checkpoint_interval = 5000 #@param {type: "integer"}

##@markdown ---
##@markdown ###Disable FastSpeech2 (used for 44.1kHz)
##@markdown This disables fastspeech for decreased model size and faster training. This works best when the 44.1kHz vocoder is released.

##@markdown For 24kHz models, it is not suggested to use this, as your old models will become incompatible, and there's not much difference in training speed for 24kHz models anyway.
#disable_fs2 = True #@param {type: "boolean"}

#@markdown ---
#@markdown ###Pretrain model usage
#@markdown This allows for faster training when in use. It is not recommended to use this if you have a sufficent amount of data (3 hours). Please don't use ATRI
use_pretrain_model = False #@param {type: "boolean"}
pretrain_model_select = "custom" #@param ["nyaru (feminine 24kHz)", "nehito (masculine 24kHz)", "opencpop (feminine 24kHz)", "liee (feminine 24kHz)", "---", "liee (feminine 44.1kHz)", "Mimi-YA EQUINOX v2 (feminine 44.1kHz)", "nehito (masculine 44.1kHz)", "custom"]

#@markdown If you choose a custom pretrained model, please point the path of the model here.
pretrain_path = "/content/drive/MyDrive/diff-svc/pretrain/model_ckpt_steps_100000.ckpt" #@param {type:"string"}

#@markdown ---
#@markdown ###Use custom save directory
#@markdown You can change the directory to save wherever you want. Default location is /diff-svc/checkpoint if unchanged.

#@markdown Please point to a directory with the singer name already specified (example /content/drive/MyDrive/diff-svc/nyaru)

use_save_dir = True #@param {type: "boolean"}

save_dir = "/content/drive/MyDrive/diff-svc/checkpoints" #@param {type: "string"}
save_dir = save_dir.replace(" ", "_")

#@markdown ---
#@markdown ###Resume training from a checkpoint

resume_training_from_ckpt = True #@param {type: "boolean"}
ckpt_directory = "/content/drive/MyDrive/diff-svc/checkpoints"#@param {type: "string"}


#@markdown ---

#@markdown ###Setup for small datasets
#@markdown If your dataset is small, each epoch will go by very fast and won't have enough time to train well, so if your dataset is considered small, use this option.

endless_ds = False #@param {type:"boolean"}

if use_save_dir:
  # %cd /content/diff-svc/utils
  # !rm -rf hparams.py
  # !wget https://github.com/prophesier/diff-svc/raw/main/utils/hparams.py
  # !sed -i -r 's|checkpoints/\{args.work_dir}|haruwashere|g' /content/diff-svc/utils/hparams.py
  # !sed -i -r 's|haruwashere|{save_dir}|g' /content/diff-svc/utils/hparams.py
  # %cd /content/
else:
  # %cd /content/diff-svc/utils
  # !rm -rf hparams.py
  # !wget https://github.com/prophesier/diff-svc/raw/main/utils/hparams.py
  # %cd /content/
clear_output()
if resume_training_from_ckpt:
  # !cp {ckpt_directory} {save_dir}
  print("Status: Resuming Training From Checkpoint")
else:
  print("Status: Not Resuming From Checkpoint")

if use_pretrain_model:
  # %mkdir -p /content/diff-svc/pretrain/
  # %cd /content/diff-svc/pretrain/
  lr = '0.00005'
  if pretrain_model_select == "nyaru (feminine 24kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/haru0l/Diff-SVC-notebooks/releases/download/models/nyaru.ckpt -q
    pretrain_path = "/content/diff-svc/pretrain/nyaru.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 24kHz (nyaru) for pretraining...")
  elif pretrain_model_select == "nehito (masculine 24kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/MLo7Ghinsan/MLo7_Diff-SVC_models/releases/download/models/Nehito-Diff-SVC_24khz.zip -q
    # !unzip Nehito-Diff-SVC_24khz.zip -d /content/diff-svc/pretrain/
    pretrain_path = "/content/diff-svc/pretrain/model_ckpt_steps_1000000.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 24kHz (nehito) for pretraining...")
  elif pretrain_model_select == "opencpop (feminine 24kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/haru0l/Diff-SVC-notebooks/releases/download/models/opencpop.ckpt -q
    pretrain_path = "/content/diff-svc/pretrain/opencpop.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 24kHz (OpenCPop) for pretraining...")
  elif pretrain_model_select == "---":
    print("Not a valid option. Defaulting to not use a pretrained model...")
  elif pretrain_model_select == "liee (feminine 24kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/julieraptor/LIEE-DIFF-SVC-AI/releases/download/Model-24kHz/model_ckpt_steps_200000.ckpt -q
    pretrain_path = "/content/diff-svc/pretrain/model_ckpt_steps_200000.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 24kHz (LIEE) for pretraining...")
  elif pretrain_model_select == "Mimi-YA EQUINOX v2 (feminine 44.1kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/Supurreme/Mimi-YA-DIFF-SVC/releases/download/eek/model_ckpt_steps_400000.ckpt -q
    pretrain_path = "/content/diff-svc/pretrain/model_ckpt_steps_400000.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 44.1kHz (Mimi-YA EQUINOX v2) for pretraining...")
  elif pretrain_model_select == "liee (feminine 44.1kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/julieraptor/LIEE-DIFF-SVC-AI/releases/download/Model-44.1kHz/model_ckpt_steps_600000.ckpt -q
    pretrain_path = "/content/diff-svc/pretrain/model_ckpt_steps_600000.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 44.1kHz (LIEE) for pretraining...")
  elif pretrain_model_select == "nehito (masculine 44.1kHz)":
    # !aria2c --file-allocation=none -c -x 10 -s 10 -d "/content/diff-svc/pretrain/" https://github.com/MLo7Ghinsan/MLo7_Diff-SVC_models/releases/download/models/Nehito-Diff-SVC_44khz.zip -q
    # !unzip Nehito-Diff-SVC_44khz.zip -d /content/diff-svc/pretrain/
    pretrain_path = "/content/diff-svc/pretrain/Nehito-Diff-SVC_44khz/nehito_ckpt_steps_1000000.ckpt"
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}
    print("Using 44.1kHz (nehito) for pretraining...")
	
  elif pretrain_model_select == "custom":
    print("Custom pretrained model selected.")
    # !sed -i -r 's|(load_ckpt:)(\s+)(.+)|\1\2{pretrain_path}|g' {config_path}

if sample_rate == "44.1kHz":
  disable_fs2 = True
  # !sed -i -r 's|(no_fs2:)(\s+)(.+)|\1\2{disable_fs2}|g' {config_path}
else:
  disable_fs2 = False
  # !sed -i -r 's|(no_fs2:)(\s+)(.+)|\1\2{disable_fs2}|g' {config_path}

# !sed -i -r 's|(max_sentences:)(\s+)(.+)|\1\2{batch_size}|g' {config_path}
# !sed -i -r 's|(decay_steps:)(\s+)(.+)|\1\2{decay_steps}|g' {config_path}
# !sed -i -r 's|(lr:)(\s+)(.+)|\1\2{lr}|g' {config_path}
# !sed -i -r 's|(K_step:)(\s+)(.+)|\1\2{K_step}|g' {config_path}
# !sed -i -r 's|(max_sentences:)(\s+)(.+)|\1\2{batch_size}|g' {config_path}
# !sed -i -r 's|(use_crepe:)(\s+)(.+)|\1\2{use_crepe}|g' {config_path}
# !sed -i -r 's|(val_check_interval:)(\s+)(.+)|\1\2{checkpoint_interval}|g' {config_path}
# !sed -i -r 's|(no_fs2:)(\s+)(.+)|\1\2{disable_fs2}|g' {config_path}
# !sed -i -r 's|(endless_ds:)(\s+)(.+)|\1\2{endless_ds}|g' {config_path}

#clear_output()
print('Done!')
# Out:
# Status: Not Resuming From Checkpoint
# /content/diff-svc/pretrain
# Custom pretrained model selected.
# Done!

# %% [markdown]
# # Training
# Finally, the dreaded part.

# %%
#@title #Step 4: Pre-processing
#@markdown This step is also known as data prep or feature generation, who cares?
#@markdown
# %cd "/content/diff-svc/"

os.environ['PYTHONPATH']='.'
# !CUDA_VISIBLE_DEVICES=0 python preprocessing/binarize.py --config {config_path}
# %cd "/content/diff-svc/data"
!7za -bso0 a "/content/{singer_name}_binary_data.7z" "binary/{singer_name}"
if not os.path.exists('/content/drive/MyDrive/diff-svc/data/{singer_name}'):
    # !mkdir -p /content/drive/MyDrive/diff-svc/data/{singer_name}
# !mv -v "/content/{singer_name}_binary_data.7z" /content/drive/MyDrive/diff-svc/data/{singer_name}
if sample_rate == "44.1kHz":
  # !cp -r /content/diff-svc/training/config_nsf.yaml /content/drive/MyDrive/diff-svc/data/{singer_name}
else:
  # !cp -r /content/diff-svc/training/config.yaml /content/drive/MyDrive/diff-svc/data/{singer_name}
# Out:
# /content/diff-svc
# | Hparams chains:  ['/content/diff-svc/training/config_nsf.yaml']
# | Hparams:
# K_step: 1000, accumulate_grad_batches: 1, audio_num_mel_bins: 128, audio_sample_rate: 44100, binarization_args: {'shuffle': False, 'with_align': True, 'with_f0': True, 'with_hubert': True, 'with_spk_embed': False, 'with_wav': False},
# binarizer_cls: preprocessing.SVCpre.SVCBinarizer, binary_data_dir: data/binary/Altoria, check_val_every_n_epoch: 10, choose_test_manually: False, clip_grad_norm: 1,
# config_path: training/config_nsf.yaml, content_cond_steps: [], cwt_add_f0_loss: False, cwt_hidden_size: 128, cwt_layers: 2,
# cwt_loss: l1, cwt_std_scale: 0.8, datasets: ['opencpop'], debug: False, dec_ffn_kernel_size: 9,
# dec_layers: 4, decay_steps: 20000, decoder_type: fft, dict_dir: , diff_decoder_type: wavenet,
# diff_loss_type: l2, dilation_cycle_length: 4, dropout: 0.1, ds_workers: 4, dur_enc_hidden_stride_kernel: ['0,2,3', '0,2,3', '0,1,3'],
# dur_loss: mse, dur_predictor_kernel: 3, dur_predictor_layers: 5, enc_ffn_kernel_size: 9, enc_layers: 4,
# encoder_K: 8, encoder_type: fft, endless_ds: False, f0_bin: 256, f0_max: 1100.0,
# f0_min: 40.0, ffn_act: gelu, ffn_padding: SAME, fft_size: 2048, fmax: 16000,
# fmin: 40, fs2_ckpt: , gaussian_start: True, gen_dir_name: , gen_tgt_spk_id: -1,
# hidden_size: 256, hop_size: 512, hubert_gpu: True, hubert_path: checkpoints/hubert/hubert_soft.pt, infer: False,
# keep_bins: 128, lambda_commit: 0.25, lambda_energy: 0.0, lambda_f0: 1.0, lambda_ph_dur: 0.3,
# lambda_sent_dur: 1.0, lambda_uv: 1.0, lambda_word_dur: 1.0, load_ckpt: , log_interval: 100,
# loud_norm: False, lr: 0.0008, max_beta: 0.02, max_epochs: 3000, max_eval_sentences: 1,
# max_eval_tokens: 60000, max_frames: 42000, max_input_tokens: 60000, max_sentences: 12, max_tokens: 128000,
# max_updates: 1000000, mel_loss: ssim:0.5|l1:0.5, mel_vmax: 1.5, mel_vmin: -6.0, min_level_db: -120,
# no_fs2: True, norm_type: gn, num_ckpt_keep: 10, num_heads: 2, num_sanity_val_steps: 1,
# num_spk: 1, num_test_samples: 0, num_valid_plots: 10, optimizer_adam_beta1: 0.9, optimizer_adam_beta2: 0.98,
# out_wav_norm: False, pe_ckpt: checkpoints/0102_xiaoma_pe/model_ckpt_steps_60000.ckpt, pe_enable: False, perform_enhance: True, pitch_ar: False,
# pitch_enc_hidden_stride_kernel: ['0,2,5', '0,2,5', '0,2,5'], pitch_extractor: parselmouth, pitch_loss: l2, pitch_norm: log, pitch_type: frame,
# pndm_speedup: 10, pre_align_args: {'allow_no_txt': False, 'denoise': False, 'forced_align': 'mfa', 'txt_processor': 'zh_g2pM', 'use_sox': True, 'use_tone': False}, pre_align_cls: data_gen.singing.pre_align.SingingPreAlign, predictor_dropout: 0.5, predictor_grad: 0.1,
# predictor_hidden: -1, predictor_kernel: 5, predictor_layers: 5, prenet_dropout: 0.5, prenet_hidden_size: 256,
# pretrain_fs_ckpt: , processed_data_dir: xxx, profile_infer: False, raw_data_dir: data/raw/Altoria, ref_norm_layer: bn,
# rel_pos: True, reset_phone_dict: True, residual_channels: 384, residual_layers: 20, save_best: False,
# save_ckpt: True, save_codes: ['configs', 'modules', 'src', 'utils'], save_f0: True, save_gt: False, schedule_type: linear,
# seed: 1234, sort_by_len: True, speaker_id: Altoria, spec_max: [0.0], spec_min: [-5.0],
# spk_cond_steps: [], stop_token_weight: 5.0, task_cls: training.task.SVC_task.SVCTask, test_ids: [], test_input_dir: ,
# test_num: 0, test_prefixes: ['test'], test_set_name: test, timesteps: 1000, train_set_name: train,
# use_crepe: True, use_denoise: False, use_energy_embed: False, use_gt_dur: False, use_gt_f0: False,
# use_midi: False, use_nsf: True, use_pitch_embed: True, use_pos_embed: True, use_spk_embed: False,
# use_spk_id: False, use_split_spk_id: False, use_uv: False, use_var_enc: False, use_vec: False,
# val_check_interval: 1000, valid_num: 0, valid_set_name: valid, validate: False, vocoder: network.vocoders.nsf_hifigan.NsfHifiGAN,
# vocoder_ckpt: checkpoints/nsf_hifigan/model, warmup_updates: 2000, wav2spec_eps: 1e-6, weight_decay: 0, win_size: 2048,
# work_dir: ,
# | Binarizer:  <class 'preprocessing.SVCpre.SVCBinarizer'>
# spkers:  {'Altoria'}
# | spk_map:  {'Altoria': 0}
# 100% 5/5 [00:29<00:00,  5.90s/it]
# | valid total duration: 54.683s
# 100% 5/5 [00:20<00:00,  4.09s/it]
# | test total duration: 54.683s
#   0% 1/4808 [00:01<2:10:27,  1.63s/it]min value is  tensor(-1.0805, device='cuda:0')
#   0% 11/4808 [00:28<3:09:08,  2.37s/it]min value is  tensor(-1.0055, device='cuda:0')
#   0% 16/4808 [00:44<4:16:30,  3.21s/it]max value is  tensor(1.0008, device='cuda:0')
#   0% 17/4808 [00:47<4:09:10,  3.12s/it]min value is  tensor(-1.0098, device='cuda:0')
# max value is  tensor(1.0586, device='cuda:0')
#   0% 18/4808 [00:53<5:15:15,  3.95s/it]min value is  tensor(-1.0432, device='cuda:0')
# max value is  tensor(1.0423, device='cuda:0')
#   0% 20/4808 [01:00<4:41:43,  3.53s/it]max value is  tensor(1.0019, device='cuda:0')
#   0% 22/4808 [01:07<4:28:53,  3.37s/it]min value is  tensor(-1.0140, device='cuda:0')
# max value is  tensor(1.0945, device='cuda:0')
#   0% 23/4808 [01:13<5:27:53,  4.11s/it]min value is  tensor(-1.1819, device='cuda:0')
# max value is  tensor(1.1253, device='cuda:0')
#   0% 24/4808 [01:15<4:38:51,  3.50s/it]max value is  tensor(1.0950, device='cuda:0')
#   1% 29/4808 [01:29<3:55:25,  2.96s/it]max value is  tensor(1.0241, device='cuda:0')
#   1% 32/4808 [01:44<5:33:50,  4.19s/it]min value is  tensor(-1.0269, device='cuda:0')
# max value is  tensor(1.0120, device='cuda:0')
#   1% 33/4808 [01:47<5:00:33,  3.78s/it]min value is  tensor(-1.1321, device='cuda:0')
#   1% 38/4808 [01:54<2:31:39,  1.91s/it]min value is  tensor(-1.0222, device='cuda:0')
#   1% 40/4808 [02:00<3:02:47,  2.30s/it]min value is  tensor(-1.0030, device='cuda:0')
#   1% 42/4808 [02:01<1:44:15,  1.31s/it]max value is  tensor(1.0049, device='cuda:0')
#   1% 43/4808 [02:02<1:43:27,  1.30s/it]min value is  tensor(-1.0541, device='cuda:0')
# max value is  tensor(1.0466, device='cuda:0')
#   1% 44/4808 [02:05<2:03:30,  1.56s/it]min value is  tensor(-1.0197, device='cuda:0')
# max value is  tensor(1.0772, device='cuda:0')
#   1% 47/4808 [02:07<1:25:51,  1.08s/it]max value is  tensor(1.0010, device='cuda:0')
#   1% 50/4808 [02:16<3:07:38,  2.37s/it]min value is  tensor(-1.0089, device='cuda:0')
# max value is  tensor(1.0014, device='cuda:0')
#   1% 51/4808 [02:18<3:02:16,  2.30s/it]min value is  tensor(-1.0016, device='cuda:0')
#   1% 52/4808 [02:22<3:32:11,  2.68s/it]min value is  tensor(-1.1318, device='cuda:0')
#   1% 55/4808 [02:29<3:24:01,  2.58s/it]min value is  tensor(-1.0481, device='cuda:0')
# max value is  tensor(1.0007, device='cuda:0')
#   1% 56/4808 [02:33<3:55:11,  2.97s/it]min value is  tensor(-1.0239, device='cuda:0')
#   1% 57/4808 [02:38<4:32:21,  3.44s/it]min value is  tensor(-1.0192, device='cuda:0')
# max value is  tensor(1.0560, device='cuda:0')
#   1% 61/4808 [02:48<3:43:26,  2.82s/it]min value is  tensor(-1.0848, device='cuda:0')
#   1% 62/4808 [02:52<3:50:01,  2.91s/it]min value is  tensor(-1.0264, device='cuda:0')
# max value is  tensor(1.0599, device='cuda:0')
#   1% 63/4808 [02:54<3:36:19,  2.74s/it]min value is  tensor(-1.0052, device='cuda:0')
#   1% 68/4808 [03:01<1:50:10,  1.39s/it]min value is  tensor(-1.0277, device='cuda:0')
#   1% 69/4808 [03:01<1:30:48,  1.15s/it]max value is  tensor(1.0381, device='cuda:0')
#   2% 74/4808 [03:06<1:26:29,  1.10s/it]min value is  tensor(-1.0397, device='cuda:0')
# max value is  tensor(1.0091, device='cuda:0')
#   2% 77/4808 [03:12<2:21:45,  1.80s/it]max value is  tensor(1.0424, device='cuda:0')
#   2% 79/4808 [03:16<2:20:37,  1.78s/it]min value is  tensor(-1.1339, device='cuda:0')
#   2% 82/4808 [03:23<2:37:01,  1.99s/it]max value is  tensor(1.0060, device='cuda:0')
#   2% 83/4808 [03:24<2:26:28,  1.86s/it]min value is  tensor(-1.0747, device='cuda:0')
# max value is  tensor(1.1311, device='cuda:0')
#   2% 84/4808 [03:30<3:54:59,  2.98s/it]min value is  tensor(-1.0027, device='cuda:0')
#   2% 86/4808 [03:32<2:47:30,  2.13s/it]min value is  tensor(-1.0192, device='cuda:0')
# max value is  tensor(1.0154, device='cuda:0')
#   2% 87/4808 [03:33<2:06:13,  1.60s/it]min value is  tensor(-1.0717, device='cuda:0')
# max value is  tensor(1.0076, device='cuda:0')
#   2% 89/4808 [03:35<1:53:50,  1.45s/it]min value is  tensor(-1.0043, device='cuda:0')
#   2% 90/4808 [03:36<1:33:29,  1.19s/it]min value is  tensor(-1.0101, device='cuda:0')
#   2% 92/4808 [03:38<1:22:32,  1.05s/it]max value is  tensor(1.0232, device='cuda:0')
#   2% 93/4808 [03:43<2:49:17,  2.15s/it]max value is  tensor(1.0298, device='cuda:0')
#   2% 94/4808 [03:46<3:14:25,  2.47s/it]min value is  tensor(-1.0415, device='cuda:0')
#   2% 95/4808 [03:50<4:00:29,  3.06s/it]max value is  tensor(1.0257, device='cuda:0')
#   2% 97/4808 [03:55<3:21:42,  2.57s/it]min value is  tensor(-1.0119, device='cuda:0')
# max value is  tensor(1.0680, device='cuda:0')
#   2% 99/4808 [04:00<3:14:08,  2.47s/it]min value is  tensor(-1.0202, device='cuda:0')
# max value is  tensor(1.0530, device='cuda:0')
#   2% 100/4808 [04:03<3:30:11,  2.68s/it]min value is  tensor(-1.0011, device='cuda:0')
#   2% 102/4808 [04:07<2:58:38,  2.28s/it]min value is  tensor(-1.0369, device='cuda:0')
# max value is  tensor(1.0266, device='cuda:0')
#   2% 107/4808 [04:18<3:13:47,  2.47s/it]min value is  tensor(-1.0580, device='cuda:0')
# max value is  tensor(1.0013, device='cuda:0')
#   2% 115/4808 [04:39<3:20:47,  2.57s/it]max value is  tensor(1.0566, device='cuda:0')
#   2% 116/4808 [04:41<3:17:34,  2.53s/it]max value is  tensor(1.0305, device='cuda:0')
#   2% 118/4808 [04:47<3:28:57,  2.67s/it]min value is  tensor(-1.0392, device='cuda:0')
# max value is  tensor(1.0183, device='cuda:0')
#   2% 119/4808 [04:49<3:11:00,  2.44s/it]min value is  tensor(-1.0049, device='cuda:0')
# max value is  tensor(1.0088, device='cuda:0')
#   3% 123/4808 [04:54<2:01:50,  1.56s/it]max value is  tensor(1.0002, device='cuda:0')
#   3% 125/4808 [04:56<1:30:52,  1.16s/it]max value is  tensor(1.0152, device='cuda:0')
#   3% 127/4808 [04:57<1:20:18,  1.03s/it]min value is  tensor(-1.0178, device='cuda:0')
#   3% 128/4808 [04:58<1:17:53,  1.00it/s]max value is  tensor(1.0691, device='cuda:0')
#   3% 132/4808 [05:08<2:40:17,  2.06s/it]min value is  tensor(-1.0010, device='cuda:0')
# max value is  tensor(1.0606, device='cuda:0')
#   3% 134/4808 [05:11<2:04:26,  1.60s/it]min value is  tensor(-1.0228, device='cuda:0')
#   3% 136/4808 [05:13<1:39:37,  1.28s/it]f0 all zero!
# | Skip item (Empty **gt** f0). item_name: data/raw/Altoria/Altoria/sav1513_SAV_018ca.wav, wav_fn: data/raw/Altoria/Altoria/sav1513_SAV_018ca.wav
#   3% 137/4808 [05:14<1:33:34,  1.20s/it]min value is  tensor(-1.0112, device='cuda:0')
#   3% 140/4808 [05:18<1:39:53,  1.28s/it]f0 all zero!
# | Skip item (Empty **gt** f0). item_name: data/raw/Altoria/Altoria/sav1513_SAV_018bd.wav, wav_fn: data/raw/Altoria/Altoria/sav1513_SAV_018bd.wav
#   3% 141/4808 [05:19<1:33:01,  1.20s/it]min value is  tensor(-1.0582, device='cuda:0')
# max value is  tensor(1.0404, device='cuda:0')
#   3% 142/4808 [05:21<1:52:57,  1.45s/it]max value is  tensor(1.0702, device='cuda:0')
#   3% 143/4808 [05:23<2:00:26,  1.55s/it]max value is  tensor(1.0291, device='cuda:0')
#   3% 147/4808 [05:32<3:22:40,  2.61s/it]min value is  tensor(-1.0088, device='cuda:0')
#   3% 148/4808 [05:36<3:49:31,  2.96s/it]min value is  tensor(-1.0095, device='cuda:0')
#   3% 149/4808 [05:39<3:47:06,  2.92s/it]min value is  tensor(-1.0300, device='cuda:0')
# max value is  tensor(1.1468, device='cuda:0')
#   3% 150/4808 [05:40<3:04:43,  2.38s/it]min value is  tensor(-1.0245, device='cuda:0')
#   3% 160/4808 [05:52<1:50:53,  1.43s/it]min value is  tensor(-1.0194, device='cuda:0')
# max value is  tensor(1.0024, device='cuda:0')
#   3% 161/4808 [05:54<2:14:58,  1.74s/it]min value is  tensor(-1.0785, device='cuda:0')
# max value is  tensor(1.0096, device='cuda:0')
#   3% 166/4808 [06:06<2:07:16,  1.65s/it]min value is  tensor(-1.0029, device='cuda:0')
#   3% 167/4808 [06:06<1:41:32,  1.31s/it]min value is  tensor(-1.0210, device='cuda:0')
#   4% 169/4808 [06:12<2:43:15,  2.11s/it]min value is  tensor(-1.0101, device='cuda:0')
# max value is  tensor(1.0055, device='cuda:0')
#   4% 171/4808 [06:19<3:58:02,  3.08s/it]min value is  tensor(-1.0088, device='cuda:0')
#   4% 172/4808 [06:23<4:10:22,  3.24s/it]min value is  tensor(-1.0095, device='cuda:0')
#   4% 173/4808 [06:26<4:00:37,  3.11s/it]min value is  tensor(-1.0300, device='cuda:0')
# max value is  tensor(1.1468, device='cuda:0')
#   4% 175/4808 [06:29<3:02:31,  2.36s/it]min value is  tensor(-1.0648, device='cuda:0')
# max value is  tensor(1.0512, device='cuda:0')
#   4% 177/4808 [06:33<2:44:16,  2.13s/it]max value is  tensor(1.0255, device='cuda:0')
#   4% 180/4808 [06:39<2:25:48,  1.89s/it]min value is  tensor(-1.0059, device='cuda:0')
#   4% 181/4808 [06:43<3:08:21,  2.44s/it]max value is  tensor(1.0201, device='cuda:0')
#   4% 182/4808 [06:44<2:46:11,  2.16s/it]min value is  tensor(-1.0026, device='cuda:0')
#   4% 183/4808 [06:46<2:32:35,  1.98s/it]max value is  tensor(1.0157, device='cuda:0')
#   4% 184/4808 [06:50<3:18:39,  2.58s/it]min value is  tensor(-1.0025, device='cuda:0')
# max value is  tensor(1.1085, device='cuda:0')
#   4% 187/4808 [06:58<3:40:36,  2.86s/it]min value is  tensor(-1.0126, device='cuda:0')
#   4% 189/4808 [07:08<4:55:18,  3.84s/it]min value is  tensor(-1.0700, device='cuda:0')
#   4% 190/4808 [07:11<4:44:35,  3.70s/it]max value is  tensor(1.0001, device='cuda:0')
#   4% 191/4808 [07:13<4:03:17,  3.16s/it]min value is  tensor(-1.0130, device='cuda:0')
# max value is  tensor(1.0241, device='cuda:0')
#   4% 192/4808 [07:14<3:26:59,  2.69s/it]max value is  tensor(1.0143, device='cuda:0')
#   4% 193/4808 [07:16<3:06:18,  2.42s/it]min value is  tensor(-1.0216, device='cuda:0')
#   4% 194/4808 [07:20<3:35:04,  2.80s/it]min value is  tensor(-1.0278, device='cuda:0')
# max value is  tensor(1.0630, device='cuda:0')
#   4% 195/4808 [07:24<4:03:57,  3.17s/it]min value is  tensor(-1.0157, device='cuda:0')
#   4% 196/4808 [07:26<3:40:30,  2.87s/it]min value is  tensor(-1.0028, device='cuda:0')
# max value is  tensor(1.0545, device='cuda:0')
#   4% 199/4808 [07:35<3:20:53,  2.62s/it]min value is  tensor(-1.0437, device='cuda:0')
#   4% 201/4808 [07:40<3:23:47,  2.65s/it]max value is  tensor(1.1078, device='cuda:0')
#   4% 202/4808 [07:44<3:50:45,  3.01s/it]max value is  tensor(1.0188, device='cuda:0')
#   4% 204/4808 [07:46<2:49:27,  2.21s/it]min value is  tensor(-1.0536, device='cuda:0')
# max value is  tensor(1.0093, device='cuda:0')
#   4% 205/4808 [07:49<2:56:01,  2.29s/it]min value is  tensor(-1.0204, device='cuda:0')
# max value is  tensor(1.0006, device='cuda:0')
#   4% 206/4808 [07:53<3:33:57,  2.79s/it]min value is  tensor(-1.0378, device='cuda:0')
# max value is  tensor(1.0350, device='cuda:0')
#   4% 208/4808 [07:59<3:40:13,  2.87s/it]min value is  tensor(-1.0470, device='cuda:0')
# max value is  tensor(1.1284, device='cuda:0')
#   4% 210/4808 [08:03<2:56:00,  2.30s/it]max value is  tensor(1.0012, device='cuda:0')
#   4% 211/4808 [08:08<4:02:44,  3.17s/it]min value is  tensor(-1.0719, device='cuda:0')
#   5% 221/4808 [08:27<3:16:46,  2.57s/it]min value is  tensor(-1.0103, device='cuda:0')
#   5% 223/4808 [08:30<2:42:38,  2.13s/it]max value is  tensor(1.0341, device='cuda:0')
#   5% 224/4808 [08:32<2:36:33,  2.05s/it]max value is  tensor(1.0133, device='cuda:0')
#   5% 226/4808 [08:34<1:55:30,  1.51s/it]min value is  tensor(-1.0288, device='cuda:0')
# max value is  tensor(1.0428, device='cuda:0')
#   5% 227/4808 [08:37<2:20:30,  1.84s/it]max value is  tensor(1.0038, device='cuda:0')
#   5% 228/4808 [08:38<1:57:19,  1.54s/it]max value is  tensor(1.0592, device='cuda:0')
#   5% 232/4808 [08:47<2:48:02,  2.20s/it]min value is  tensor(-1.0207, device='cuda:0')
#   5% 234/4808 [08:53<3:16:13,  2.57s/it]min value is  tensor(-1.0375, device='cuda:0')
#   5% 239/4808 [09:05<2:41:57,  2.13s/it]min value is  tensor(-1.0546, device='cuda:0')
# max value is  tensor(1.0783, device='cuda:0')
#   5% 241/4808 [09:10<2:54:41,  2.30s/it]max value is  tensor(1.0117, device='cuda:0')
#   5% 242/4808 [09:12<2:49:34,  2.23s/it]min value is  tensor(-1.0126, device='cuda:0')
# max value is  tensor(1.0763, device='cuda:0')
#   5% 243/4808 [09:15<2:57:48,  2.34s/it]min value is  tensor(-1.0105, device='cuda:0')
# max value is  tensor(1.0019, device='cuda:0')
#   5% 251/4808 [09:31<2:06:10,  1.66s/it]min value is  tensor(-1.0549, device='cuda:0')
# max value is  tensor(1.0281, device='cuda:0')
#   5% 260/4808 [09:50<1:54:58,  1.52s/it]max value is  tensor(1.0143, device='cuda:0')
#   5% 263/4808 [10:00<3:55:20,  3.11s/it]max value is  tensor(1.0345, device='cuda:0')
#   6% 266/4808 [10:06<3:00:49,  2.39s/it]min value is  tensor(-1.0357, device='cuda:0')
#   6% 268/4808 [10:12<3:30:56,  2.79s/it]min value is  tensor(-1.0717, device='cuda:0')
#   6% 273/4808 [10:24<2:55:21,  2.32s/it]min value is  tensor(-1.0204, device='cuda:0')
#   6% 284/4808 [10:48<2:48:34,  2.24s/it]min value is  tensor(-1.0147, device='cuda:0')
#   6% 285/4808 [10:51<3:13:22,  2.57s/it]min value is  tensor(-1.0386, device='cuda:0')
# max value is  tensor(1.0808, device='cuda:0')
#   6% 295/4808 [11:09<2:42:09,  2.16s/it]min value is  tensor(-1.0255, device='cuda:0')
# max value is  tensor(1.0258, device='cuda:0')
#   6% 296/4808 [11:13<3:29:01,  2.78s/it]min value is  tensor(-1.0321, device='cuda:0')
#   6% 300/4808 [11:23<2:58:54,  2.38s/it]max value is  tensor(1.0051, device='cuda:0')
#   6% 304/4808 [11:33<2:52:11,  2.29s/it]min value is  tensor(-1.0500, device='cuda:0')
#   6% 305/4808 [11:34<2:17:20,  1.83s/it]min value is  tensor(-1.0067, device='cuda:0')
# max value is  tensor(1.0976, device='cuda:0')
#   6% 309/4808 [11:44<3:19:38,  2.66s/it]min value is  tensor(-1.0135, device='cuda:0')
# max value is  tensor(1.0332, device='cuda:0')
#   6% 312/4808 [11:51<2:45:14,  2.21s/it]min value is  tensor(-1.0009, device='cuda:0')
#   7% 320/4808 [12:07<2:42:03,  2.17s/it]max value is  tensor(1.0020, device='cuda:0')
#   7% 322/4808 [12:12<2:56:34,  2.36s/it]min value is  tensor(-1.1177, device='cuda:0')
# max value is  tensor(1.1136, device='cuda:0')
#   7% 325/4808 [12:18<2:20:05,  1.88s/it]min value is  tensor(-1.0128, device='cuda:0')
# max value is  tensor(1.0046, device='cuda:0')
#   7% 327/4808 [12:22<2:25:57,  1.95s/it]min value is  tensor(-1.0568, device='cuda:0')
# max value is  tensor(1.0016, device='cuda:0')
#   7% 328/4808 [12:26<3:07:01,  2.50s/it]min value is  tensor(-1.0062, device='cuda:0')
#   7% 329/4808 [12:27<2:43:49,  2.19s/it]min value is  tensor(-1.0084, device='cuda:0')
#   7% 333/4808 [12:35<2:13:53,  1.80s/it]min value is  tensor(-1.0031, device='cuda:0')
#   7% 334/4808 [12:38<2:36:42,  2.10s/it]max value is  tensor(1.0033, device='cuda:0')
#   7% 335/4808 [12:40<2:51:19,  2.30s/it]min value is  tensor(-1.0302, device='cuda:0')
# max value is  tensor(1.0785, device='cuda:0')
#   7% 336/4808 [12:43<2:57:39,  2.38s/it]max value is  tensor(1.0026, device='cuda:0')
#   7% 338/4808 [12:47<2:32:01,  2.04s/it]min value is  tensor(-1.0034, device='cuda:0')
# max value is  tensor(1.0649, device='cuda:0')
#   7% 339/4808 [12:49<2:46:11,  2.23s/it]min value is  tensor(-1.0396, device='cuda:0')
# max value is  tensor(1.0031, device='cuda:0')
#   7% 340/4808 [12:53<3:06:01,  2.50s/it]min value is  tensor(-1.0612, device='cuda:0')
# max value is  tensor(1.0463, device='cuda:0')
#   7% 343/4808 [12:57<2:12:15,  1.78s/it]f0 all zero!
# | Skip item (Empty **gt** f0). item_name: data/raw/Altoria/Altoria/sav1409_SAV_02036.wav, wav_fn: data/raw/Altoria/Altoria/sav1409_SAV_02036.wav
#   7% 345/4808 [12:58<1:26:32,  1.16s/it]min value is  tensor(-1.0214, device='cuda:0')
# max value is  tensor(1.0027, device='cuda:0')
#   7% 346/4808 [13:00<1:40:52,  1.36s/it]max value is  tensor(1.0081, device='cuda:0')
#   7% 348/4808 [13:04<2:16:13,  1.83s/it]min value is  tensor(-1.0506, device='cuda:0')
# max value is  tensor(1.0743, device='cuda:0')
#   7% 350/4808 [13:09<2:29:10,  2.01s/it]min value is  tensor(-1.0039, device='cuda:0')
#   7% 354/4808 [13:19<2:38:06,  2.13s/it]max value is  tensor(1.0011, device='cuda:0')
#   7% 355/4808 [13:23<3:21:10,  2.71s/it]min value is  tensor(-1.0041, device='cuda:0')
#   7% 356/4808 [13:25<3:06:51,  2.52s/it]min value is  tensor(-1.0361, device='cuda:0')
# max value is  tensor(1.0826, device='cuda:0')
#   7% 359/4808 [13:34<3:10:59,  2.58s/it]min value is  tensor(-1.0132, device='cuda:0')
#   8% 361/4808 [13:41<3:47:49,  3.07s/it]max value is  tensor(1.0431, device='cuda:0')
#   8% 364/4808 [13:47<2:34:25,  2.08s/it]min value is  tensor(-1.0427, device='cuda:0')
#   8% 365/4808 [13:52<3:29:08,  2.82s/it]min value is  tensor(-1.0164, device='cuda:0')
#   8% 366/4808 [13:56<3:53:11,  3.15s/it]min value is  tensor(-1.0447, device='cuda:0')
#   8% 368/4808 [14:03<4:15:08,  3.45s/it]min value is  tensor(-1.0038, device='cuda:0')
# max value is  tensor(1.0321, device='cuda:0')
#   8% 369/4808 [14:07<4:15:33,  3.45s/it]min value is  tensor(-1.0044, device='cuda:0')
# max value is  tensor(1.0187, device='cuda:0')
#   8% 371/4808 [14:13<3:48:37,  3.09s/it]min value is  tensor(-1.0692, device='cuda:0')
# max value is  tensor(1.0262, device='cuda:0')
#   8% 372/4808 [14:16<3:56:49,  3.20s/it]min value is  tensor(-1.0348, device='cuda:0')
#   8% 373/4808 [14:19<3:53:24,  3.16s/it]min value is  tensor(-1.0233, device='cuda:0')
# max value is  tensor(1.1046, device='cuda:0')
#   8% 375/4808 [14:24<3:16:37,  2.66s/it]min value is  tensor(-1.0756, device='cuda:0')
# max value is  tensor(1.0593, device='cuda:0')
#   8% 376/4808 [14:27<3:25:48,  2.79s/it]min value is  tensor(-1.1103, device='cuda:0')
# max value is  tensor(1.1286, device='cuda:0')
#   8% 377/4808 [14:31<4:05:58,  3.33s/it]min value is  tensor(-1.1522, device='cuda:0')
# max value is  tensor(1.0258, device='cuda:0')
#   8% 378/4808 [14:37<4:53:00,  3.97s/it]min value is  tensor(-1.0386, device='cuda:0')
# max value is  tensor(1.0663, device='cuda:0')
#   8% 379/4808 [14:40<4:24:01,  3.58s/it]min value is  tensor(-1.0146, device='cuda:0')
#   8% 381/4808 [14:47<4:28:00,  3.63s/it]max value is  tensor(1.0105, device='cuda:0')
#   8% 384/4808 [14:50<2:14:24,  1.82s/it]min value is  tensor(-1.0756, device='cuda:0')
# max value is  tensor(1.0348, device='cuda:0')
#   8% 385/4808 [14:57<3:58:42,  3.24s/it]min value is  tensor(-1.1569, device='cuda:0')
# max value is  tensor(1.0351, device='cuda:0')
#   8% 386/4808 [15:01<4:25:34,  3.60s/it]min value is  tensor(-1.0441, device='cuda:0')
#   8% 387/4808 [15:04<4:02:51,  3.30s/it]min value is  tensor(-1.0898, device='cuda:0')
# max value is  tensor(1.1447, device='cuda:0')
#   8% 388/4808 [15:09<4:49:04,  3.92s/it]min value is  tensor(-1.0360, device='cuda:0')
# max value is  tensor(1.0943, device='cuda:0')
#   8% 389/4808 [15:12<4:34:18,  3.72s/it]min value is  tensor(-1.0042, device='cuda:0')
# max value is  tensor(1.0154, device='cuda:0')
#   8% 390/4808 [15:15<4:17:33,  3.50s/it]min value is  tensor(-1.0177, device='cuda:0')
# max value is  tensor(1.0529, device='cuda:0')
#   8% 394/4808 [15:25<2:54:19,  2.37s/it]min value is  tensor(-1.1066, device='cuda:0')
# max value is  tensor(1.0907, device='cuda:0')
#   8% 397/4808 [15:30<2:04:30,  1.69s/it]min value is  tensor(-1.0659, device='cuda:0')
# max value is  tensor(1.1073, device='cuda:0')
#   8% 398/4808 [15:34<2:57:47,  2.42s/it]min value is  tensor(-1.0518, device='cuda:0')
#   8% 399/4808 [15:36<2:56:03,  2.40s/it]min value is  tensor(-1.0817, device='cuda:0')
# max value is  tensor(1.0336, device='cuda:0')
#   8% 401/4808 [15:45<4:03:45,  3.32s/it]max value is  tensor(1.0768, device='cuda:0')
#   8% 403/4808 [15:48<2:35:13,  2.11s/it]min value is  tensor(-1.0464, device='cuda:0')
# max value is  tensor(1.0608, device='cuda:0')
#   8% 404/4808 [15:51<2:58:37,  2.43s/it]min value is  tensor(-1.0073, device='cuda:0')
#   8% 405/4808 [15:54<3:25:48,  2.80s/it]min value is  tensor(-1.0110, device='cuda:0')
#   8% 406/4808 [15:57<3:32:10,  2.89s/it]min value is  tensor(-1.1080, device='cuda:0')
# max value is  tensor(1.0408, device='cuda:0')
#   8% 407/4808 [16:02<4:11:36,  3.43s/it]min value is  tensor(-1.0531, device='cuda:0')
# max value is  tensor(1.0319, device='cuda:0')
#   9% 409/4808 [16:07<3:16:11,  2.68s/it]max value is  tensor(1.0556, device='cuda:0')
#   9% 411/4808 [16:12<3:11:25,  2.61s/it]min value is  tensor(-1.0033, device='cuda:0')
# max value is  tensor(1.0043, device='cuda:0')
#   9% 412/4808 [16:16<3:44:06,  3.06s/it]min value is  tensor(-1.0109, device='cuda:0')
#   9% 413/4808 [16:18<3:20:51,  2.74s/it]max value is  tensor(1.0052, device='cuda:0')
#   9% 416/4808 [16:26<3:12:03,  2.62s/it]max value is  tensor(1.0462, device='cuda:0')
#   9% 417/4808 [16:28<2:58:54,  2.44s/it]min value is  tensor(-1.0565, device='cuda:0')
# max value is  tensor(1.0855, device='cuda:0')
#   9% 418/4808 [16:28<2:18:08,  1.89s/it]min value is  tensor(-1.0340, device='cuda:0')
#   9% 420/4808 [16:29<1:27:31,  1.20s/it]f0 all zero!
# | Skip item (Empty **gt** f0). item_name: data/raw/Altoria/Altoria/sav1404_SAV_01f83.wav, wav_fn: data/raw/Altoria/Altoria/sav1404_SAV_01f83.wav
#   9% 422/4808 [16:30<59:54,  1.22it/s]  min value is  tensor(-1.0094, device='cuda:0')
# max value is  tensor(1.0185, device='cuda:0')
#   9% 423/4808 [16:33<1:32:31,  1.27s/it]min value is  tensor(-1.0650, device='cuda:0')
#   9% 424/4808 [16:34<1:39:57,  1.37s/it]max value is  tensor(1.0226, device='cuda:0')
#   9% 426/4808 [16:42<3:06:21,  2.55s/it]max value is  tensor(1.0180, device='cuda:0')
#   9% 427/4808 [16:45<3:11:09,  2.62s/it]min value is  tensor(-1.0487, device='cuda:0')
# max value is  tensor(1.0073, device='cuda:0')
#   9% 428/4808 [16:47<2:49:26,  2.32s/it]max value is  tensor(1.0566, device='cuda:0')
#   9% 429/4808 [16:48<2:35:05,  2.13s/it]min value is  tensor(-1.0199, device='cuda:0')
# max value is  tensor(1.0362, device='cuda:0')
#   9% 431/4808 [16:51<2:07:29,  1.75s/it]min value is  tensor(-1.0058, device='cuda:0')
#   9% 432/4808 [16:53<2:05:39,  1.72s/it]min value is  tensor(-1.0017, device='cuda:0')
# max value is  tensor(1.0092, device='cuda:0')
#   9% 434/4808 [16:59<2:43:50,  2.25s/it]min value is  tensor(-1.0154, device='cuda:0')
#   9% 435/4808 [17:01<2:43:49,  2.25s/it]min value is  tensor(-1.0590, device='cuda:0')
# max value is  tensor(1.0389, device='cuda:0')
#   9% 440/4808 [17:11<2:11:33,  1.81s/it]max value is  tensor(1.0129, device='cuda:0')
#   9% 442/4808 [17:12<1:24:11,  1.16s/it]min value is  tensor(-1.0025, device='cuda:0')
#   9% 444/4808 [17:14<1:11:25,  1.02it/s]min value is  tensor(-1.0108, device='cuda:0')
#   9% 445/4808 [17:15<1:28:01,  1.21s/it]min value is  tensor(-1.0005, device='cuda:0')
#   9% 449/4808 [17:20<1:13:59,  1.02s/it]min value is  tensor(-1.0777, device='cuda:0')
# max value is  tensor(1.0044, device='cuda:0')
#   9% 450/4808 [17:24<2:34:08,  2.12s/it]min value is  tensor(-1.0627, device='cuda:0')
# max value is  tensor(1.0374, device='cuda:0')
#   9% 451/4808 [17:26<2:25:58,  2.01s/it]min value is  tensor(-1.1301, device='cuda:0')
# max value is  tensor(1.0066, device='cuda:0')
#   9% 452/4808 [17:28<2:23:51,  1.98s/it]min value is  tensor(-1.0742, device='cuda:0')
# max value is  tensor(1.0069, device='cuda:0')
#   9% 454/4808 [17:34<2:48:52,  2.33s/it]min value is  tensor(-1.0303, device='cuda:0')
#  10% 460/4808 [17:40<1:39:27,  1.37s/it]max value is  tensor(1.0513, device='cuda:0')
#  10% 468/4808 [17:50<1:39:18,  1.37s/it]max value is  tensor(1.0010, device='cuda:0')
#  10% 471/4808 [17:54<1:29:14,  1.23s/it]max value is  tensor(1.0526, device='cuda:0')
#  10% 473/4808 [17:57<1:27:47,  1.22s/it]min value is  tensor(-1.0164, device='cuda:0')
#  10% 475/4808 [17:58<1:02:30,  1.16it/s]max value is  tensor(1.0009, device='cuda:0')
#  10% 476/4808 [18:00<1:32:44,  1.28s/it]min value is  tensor(-1.0198, device='cuda:0')
# max value is  tensor(1.0128, device='cuda:0')
#  10% 479/4808 [18:04<1:18:02,  1.08s/it]min value is  tensor(-1.0528, device='cuda:0')
# max value is  tensor(1.0923, device='cuda:0')
#  10% 480/4808 [18:08<2:23:54,  2.00s/it]min value is  tensor(-1.0951, device='cuda:0')
# max value is  tensor(1.1244, device='cuda:0')
#  10% 482/4808 [18:12<2:19:58,  1.94s/it]min value is  tensor(-1.0184, device='cuda:0')
# max value is  tensor(1.0040, device='cuda:0')
#  10% 483/4808 [18:15<2:50:36,  2.37s/it]min value is  tensor(-1.0112, device='cuda:0')
#  10% 484/4808 [18:16<2:15:59,  1.89s/it]min value is  tensor(-1.0334, device='cuda:0')
# max value is  tensor(1.0142, device='cuda:0')
#  10% 485/4808 [18:21<3:24:23,  2.84s/it]min value is  tensor(-1.0327, device='cuda:0')
# max value is  tensor(1.0689, device='cuda:0')
#  10% 486/4808 [18:27<4:25:26,  3.69s/it]min value is  tensor(-1.0038, device='cuda:0')
#  10% 488/4808 [18:30<3:19:33,  2.77s/it]min value is  tensor(-1.0415, device='cuda:0')
# max value is  tensor(1.0622, device='cuda:0')
#  10% 489/4808 [18:33<3:15:19,  2.71s/it]min value is  tensor(-1.0227, device='cuda:0')
#  10% 491/4808 [18:38<3:02:37,  2.54s/it]min value is  tensor(-1.0005, device='cuda:0')
#  10% 492/4808 [18:38<2:23:17,  1.99s/it]min value is  tensor(-1.0447, device='cuda:0')
#  10% 494/4808 [18:43<2:32:37,  2.12s/it]min value is  tensor(-1.0643, device='cuda:0')
# max value is  tensor(1.0009, device='cuda:0')
#  10% 495/4808 [18:46<2:43:09,  2.27s/it]min value is  tensor(-1.0061, device='cuda:0')
#  10% 496/4808 [18:47<2:30:44,  2.10s/it]min value is  tensor(-1.0068, device='cuda:0')
# max value is  tensor(1.0157, device='cuda:0')
#  10% 497/4808 [18:53<3:51:44,  3.23s/it]min value is  tensor(-1.0182, device='cuda:0')
# max value is  tensor(1.0223, device='cuda:0')
#  10% 498/4808 [18:56<3:49:01,  3.19s/it]min value is  tensor(-1.0740, device='cuda:0')
# max value is  tensor(1.0149, device='cuda:0')
#  10% 499/4808 [18:58<3:26:43,  2.88s/it]min value is  tensor(-1.0092, device='cuda:0')
# max value is  tensor(1.0236, device='cuda:0')
#  10% 500/4808 [19:01<3:15:04,  2.72s/it]max value is  tensor(1.0036, device='cuda:0')
#  10% 501/4808 [19:02<2:51:00,  2.38s/it]max value is  tensor(1.0052, device='cuda:0')
#  10% 502/4808 [19:03<2:10:24,  1.82s/it]max value is  tensor(1.0120, device='cuda:0')
#  10% 503/4808 [19:04<2:07:49,  1.78s/it]min value is  tensor(-1.0948, device='cuda:0')
# max value is  tensor(1.0419, device='cuda:0')
#  10% 504/4808 [19:08<2:53:28,  2.42s/it]min value is  tensor(-1.0907, device='cuda:0')
# max value is  tensor(1.0282, device='cuda:0')
#  11% 505/4808 [19:10<2:30:52,  2.10s/it]min value is  tensor(-1.0044, device='cuda:0')
#  11% 507/4808 [19:11<1:39:20,  1.39s/it]min value is  tensor(-1.1354, device='cuda:0')
# max value is  tensor(1.1360, device='cuda:0')
#  11% 509/4808 [19:13<1:13:24,  1.02s/it]min value is  tensor(-1.1162, device='cuda:0')
# max value is  tensor(1.1303, device='cuda:0')
#  11% 511/4808 [19:16<1:42:39,  1.43s/it]min value is  tensor(-1.0596, device='cuda:0')
# max value is  tensor(1.0410, device='cuda:0')
#  11% 515/4808 [19:24<2:46:46,  2.33s/it]max value is  tensor(1.0492, device='cuda:0')
#  11% 517/4808 [19:28<2:26:02,  2.04s/it]min value is  tensor(-1.1138, device='cuda:0')
# max value is  tensor(1.0067, device='cuda:0')
#  11% 518/4808 [19:33<3:25:23,  2.87s/it]min value is  tensor(-1.0375, device='cuda:0')
# max value is  tensor(1.0345, device='cuda:0')
#  11% 519/4808 [19:38<4:08:19,  3.47s/it]min value is  tensor(-1.0418, device='cuda:0')
# max value is  tensor(1.0110, device='cuda:0')
#  11% 520/4808 [19:43<4:49:02,  4.04s/it]min value is  tensor(-1.0152, device='cuda:0')
# max value is  tensor(1.0763, device='cuda:0')
#  11% 522/4808 [19:50<4:28:23,  3.76s/it]max value is  tensor(1.0231, device='cuda:0')
#  11% 523/4808 [19:56<5:04:09,  4.26s/it]min value is  tensor(-1.0262, device='cuda:0')
# max value is  tensor(1.0720, device='cuda:0')
#  11% 525/4808 [19:59<3:27:59,  2.91s/it]min value is  tensor(-1.0175, device='cuda:0')
# max value is  tensor(1.0309, device='cuda:0')
#  11% 526/4808 [20:05<4:28:25,  3.76s/it]min value is  tensor(-1.0201, device='cuda:0')
# max value is  tensor(1.0280, device='cuda:0')
#  11% 527/4808 [20:08<4:04:48,  3.43s/it]min value is  tensor(-1.0150, device='cuda:0')
# max value is  tensor(1.0658, device='cuda:0')
#  11% 528/4808 [20:12<4:11:14,  3.52s/it]min value is  tensor(-1.0340, device='cuda:0')
#  11% 531/4808 [20:17<2:53:56,  2.44s/it]max value is  tensor(1.0373, device='cuda:0')
#  11% 532/4808 [20:19<2:43:58,  2.30s/it]min value is  tensor(-1.0137, device='cuda:0')
# max value is  tensor(1.0799, device='cuda:0')
#  11% 533/4808 [20:27<4:34:08,  3.85s/it]max value is  tensor(1.0069, device='cuda:0')
#  11% 534/4808 [20:31<4:45:28,  4.01s/it]min value is  tensor(-1.0870, device='cuda:0')
# max value is  tensor(1.0820, device='cuda:0')
#  11% 535/4808 [20:34<4:30:57,  3.80s/it]min value is  tensor(-1.0463, device='cuda:0')
# max value is  tensor(1.0227, device='cuda:0')
#  11% 537/4808 [20:41<4:12:18,  3.54s/it]max value is  tensor(1.0460, device='cuda:0')
#  11% 538/4808 [20:44<4:08:08,  3.49s/it]min value is  tensor(-1.0278, device='cuda:0')
# max value is  tensor(1.0436, device='cuda:0')
#  11% 539/4808 [20:48<4:12:42,  3.55s/it]min value is  tensor(-1.0197, device='cuda:0')
# max value is  tensor(1.0552, device='cuda:0')
#  11% 541/4808 [20:54<3:43:04,  3.14s/it]min value is  tensor(-1.1260, device='cuda:0')
# max value is  tensor(1.0723, device='cuda:0')
#  11% 542/4808 [20:56<3:17:44,  2.78s/it]max value is  tensor(1.1749, device='cuda:0')
#  11% 543/4808 [20:59<3:18:45,  2.80s/it]min value is  tensor(-1.0403, device='cuda:0')
# max value is  tensor(1.0267, device='cuda:0')
#  11% 545/4808 [21:05<3:26:36,  2.91s/it]min value is  tensor(-1.0860, device='cuda:0')
#  11% 546/4808 [21:07<3:03:26,  2.58s/it]min value is  tensor(-1.0542, device='cuda:0')
# max value is  tensor(1.0505, device='cuda:0')
#  11% 547/4808 [21:10<3:20:39,  2.83s/it]min value is  tensor(-1.0740, device='cuda:0')
# max value is  tensor(1.0797, device='cuda:0')
#  11% 549/4808 [21:17<3:39:32,  3.09s/it]max value is  tensor(1.0292, device='cuda:0')
#  11% 551/4808 [21:28<4:53:42,  4.14s/it]min value is  tensor(-1.0905, device='cuda:0')
# max value is  tensor(1.0391, device='cuda:0')
#  11% 552/4808 [21:30<4:13:17,  3.57s/it]min value is  tensor(-1.0556, device='cuda:0')
# max value is  tensor(1.0242, device='cuda:0')
#  12% 554/4808 [21:38<4:42:02,  3.98s/it]max value is  tensor(1.0092, device='cuda:0')
#  12% 555/4808 [21:41<4:17:10,  3.63s/it]min value is  tensor(-1.0099, device='cuda:0')
#  12% 557/4808 [21:45<3:18:17,  2.80s/it]min value is  tensor(-1.0698, device='cuda:0')
#  12% 561/4808 [21:53<2:22:42,  2.02s/it]min value is  tensor(-1.1047, device='cuda:0')
# max value is  tensor(1.0571, device='cuda:0')
#  12% 563/4808 [21:58<2:38:22,  2.24s/it]min value is  tensor(-1.0651, device='cuda:0')
# max value is  tensor(1.0360, device='cuda:0')
#  12% 564/4808 [22:01<3:04:53,  2.61s/it]min value is  tensor(-1.0450, device='cuda:0')
# max value is  tensor(1.0617, device='cuda:0')
#  12% 565/4808 [22:08<4:38:44,  3.94s/it]min value is  tensor(-1.0206, device='cuda:0')
# max value is  tensor(1.0107, device='cuda:0')
#  12% 567/4808 [22:11<3:08:48,  2.67s/it]min value is  tensor(-1.0396, device='cuda:0')
# max value is  tensor(1.0673, device='cuda:0')
#  12% 570/4808 [22:21<3:36:43,  3.07s/it]min value is  tensor(-1.0218, device='cuda:0')
# max value is  tensor(1.0667, device='cuda:0')
#  12% 571/4808 [22:24<3:32:03,  3.00s/it]min value is  tensor(-1.0873, device='cuda:0')
# max value is  tensor(1.0006, device='cuda:0')
#  12% 572/4808 [22:26<3:02:55,  2.59s/it]min value is  tensor(-1.0559, device='cuda:0')
# max value is  tensor(1.0248, device='cuda:0')
#  12% 574/4808 [22:30<2:36:31,  2.22s/it]min value is  tensor(-1.0720, device='cuda:0')
# max value is  tensor(1.1814, device='cuda:0')
#  12% 575/4808 [22:34<3:33:40,  3.03s/it]min value is  tensor(-1.0664, device='cuda:0')
#  12% 576/4808 [22:39<4:00:53,  3.42s/it]min value is  tensor(-1.0277, device='cuda:0')
# max value is  tensor(1.0321, device='cuda:0')
#  12% 577/4808 [22:43<4:27:17,  3.79s/it]min value is  tensor(-1.0035, device='cuda:0')
# max value is  tensor(1.0027, device='cuda:0')
#  12% 579/4808 [22:52<4:21:10,  3.71s/it]min value is  tensor(-1.1356, device='cuda:0')
# max value is  tensor(1.0525, device='cuda:0')
#  12% 580/4808 [22:58<5:22:07,  4.57s/it]min value is  tensor(-1.0349, device='cuda:0')
#  12% 582/4808 [23:04<4:18:58,  3.68s/it]max value is  tensor(1.0371, device='cuda:0')
#  12% 583/4808 [23:08<4:35:41,  3.92s/it]min value is  tensor(-1.0692, device='cuda:0')
#  12% 584/4808 [23:10<3:55:48,  3.35s/it]min value is  tensor(-1.0957, device='cuda:0')
# max value is  tensor(1.0288, device='cuda:0')
#  12% 586/4808 [23:15<3:09:14,  2.69s/it]min value is  tensor(-1.1022, device='cuda:0')
# max value is  tensor(1.0603, device='cuda:0')
#  12% 587/4808 [23:18<3:25:56,  2.93s/it]min value is  tensor(-1.0095, device='cuda:0')
# max value is  tensor(1.0136, device='cuda:0')
#  12% 590/4808 [23:24<2:38:34,  2.26s/it]min value is  tensor(-1.0259, device='cuda:0')
# max value is  tensor(1.0770, device='cuda:0')
#  12% 591/4808 [23:30<3:58:38,  3.40s/it]max value is  tensor(1.0095, device='cuda:0')
#  12% 593/4808 [23:35<3:37:39,  3.10s/it]max value is  tensor(1.0072, device='cuda:0')
#  12% 594/4808 [23:37<3:02:20,  2.60s/it]max value is  tensor(1.1056, device='cuda:0')
#  12% 595/4808 [23:40<3:08:42,  2.69s/it]min value is  tensor(-1.0102, device='cuda:0')
# max value is  tensor(1.0756, device='cuda:0')
#  12% 596/4808 [23:41<2:46:50,  2.38s/it]min value is  tensor(-1.0001, device='cuda:0')
#  12% 598/4808 [23:44<2:06:47,  1.81s/it]min value is  tensor(-1.0893, device='cuda:0')
#  12% 599/4808 [23:46<2:17:17,  1.96s/it]min value is  tensor(-1.0593, device='cuda:0')
# max value is  tensor(1.1331, device='cuda:0')
#  12% 601/4808 [23:51<2:16:08,  1.94s/it]min value is  tensor(-1.0140, device='cuda:0')
# max value is  tensor(1.0603, device='cuda:0')
#  13% 605/4808 [24:02<3:08:39,  2.69s/it]max value is  tensor(1.0085, device='cuda:0')
#  13% 608/4808 [24:09<2:42:11,  2.32s/it]min value is  tensor(-1.0281, device='cuda:0')
# max value is  tensor(1.0563, device='cuda:0')
#  13% 609/4808 [24:11<2:31:14,  2.16s/it]min value is  tensor(-1.0013, device='cuda:0')
# max value is  tensor(1.0051, device='cuda:0')
#  13% 616/4808 [24:20<1:44:39,  1.50s/it]min value is  tensor(-1.0502, device='cuda:0')
# max value is  tensor(1.0020, device='cuda:0')
#  13% 617/4808 [24:23<2:00:39,  1.73s/it]max value is  tensor(1.0221, device='cuda:0')
#  13% 618/4808 [24:24<1:55:12,  1.65s/it]min value is  tensor(-1.0204, device='cuda:0')
# max value is  tensor(1.0356, device='cuda:0')
#  13% 619/4808 [24:29<2:56:03,  2.52s/it]min value is  tensor(-1.0028, device='cuda:0')
#  13% 620/4808 [24:29<2:15:25,  1.94s/it]max value is  tensor(1.0278, device='cuda:0')
#  13% 621/4808 [24:37<4:23:06,  3.77s/it]min value is  tensor(-1.0584, device='cuda:0')
# max value is  tensor(1.0409, device='cuda:0')
#  13% 622/4808 [24:38<3:29:45,  3.01s/it]min value is  tensor(-1.0039, device='cuda:0')
# max value is  tensor(1.0124, device='cuda:0')
#  13% 623/4808 [24:42<3:37:41,  3.12s/it]min value is  tensor(-1.0651, device='cuda:0')
#  13% 624/4808 [24:43<2:53:04,  2.48s/it]min value is  tensor(-1.0288, device='cuda:0')
#  13% 625/4808 [24:45<2:36:43,  2.25s/it]min value is  tensor(-1.0175, device='cuda:0')
#  13% 626/4808 [24:46<2:19:16,  2.00s/it]min value is  tensor(-1.0030, device='cuda:0')
#  13% 627/4808 [24:47<1:57:34,  1.69s/it]min value is  tensor(-1.0342, device='cuda:0')
# max value is  tensor(1.0349, device='cuda:0')
#  13% 629/4808 [24:50<1:44:06,  1.49s/it]max value is  tensor(1.0432, device='cuda:0')
#  13% 630/4808 [24:52<2:09:26,  1.86s/it]min value is  tensor(-1.0329, device='cuda:0')
# max value is  tensor(1.0383, device='cuda:0')
#  13% 631/4808 [24:55<2:21:36,  2.03s/it]min value is  tensor(-1.0312, device='cuda:0')
#  13% 632/4808 [24:56<1:51:16,  1.60s/it]min value is  tensor(-1.0640, device='cuda:0')
# max value is  tensor(1.1379, device='cuda:0')
#  13% 633/4808 [25:01<3:02:36,  2.62s/it]min value is  tensor(-1.0606, device='cuda:0')
#  13% 636/4808 [25:08<2:42:00,  2.33s/it]min value is  tensor(-1.0253, device='cuda:0')
#  13% 637/4808 [25:10<2:36:30,  2.25s/it]min value is  tensor(-1.0286, device='cuda:0')
#  13% 638/4808 [25:13<2:40:04,  2.30s/it]max value is  tensor(1.1001, device='cuda:0')
#  13% 639/4808 [25:14<2:11:04,  1.89s/it]max value is  tensor(1.0542, device='cuda:0')
#  13% 641/4808 [25:18<2:14:38,  1.94s/it]max value is  tensor(1.0030, device='cuda:0')
#  13% 642/4808 [25:20<2:09:21,  1.86s/it]min value is  tensor(-1.0252, device='cuda:0')
# max value is  tensor(1.0081, device='cuda:0')
#  13% 644/4808 [25:25<2:37:03,  2.26s/it]min value is  tensor(-1.0181, device='cuda:0')
# max value is  tensor(1.0322, device='cuda:0')
#  13% 645/4808 [25:28<2:49:17,  2.44s/it]max value is  tensor(1.0099, device='cuda:0')
#  13% 646/4808 [25:29<2:28:38,  2.14s/it]min value is  tensor(-1.0422, device='cuda:0')
#  13% 647/4808 [25:33<2:57:25,  2.56s/it]min value is  tensor(-1.0452, device='cuda:0')
#  13% 648/4808 [25:35<2:49:44,  2.45s/it]max value is  tensor(1.0032, device='cuda:0')
#  13% 649/4808 [25:37<2:38:49,  2.29s/it]min value is  tensor(-1.0278, device='cuda:0')
# max value is  tensor(1.0647, device='cuda:0')
#  14% 651/4808 [25:42<2:50:07,  2.46s/it]min value is  tensor(-1.0184, device='cuda:0')
#  14% 652/4808 [25:45<2:59:12,  2.59s/it]min value is  tensor(-1.1177, device='cuda:0')
# max value is  tensor(1.0067, device='cuda:0')
#  14% 653/4808 [25:51<4:05:17,  3.54s/it]min value is  tensor(-1.0615, device='cuda:0')
# max value is  tensor(1.0605, device='cuda:0')
#  14% 655/4808 [25:58<4:05:23,  3.55s/it]max value is  tensor(1.0320, device='cuda:0')
#  14% 656/4808 [26:01<3:57:54,  3.44s/it]max value is  tensor(1.0215, device='cuda:0')
#  14% 657/4808 [26:02<3:09:57,  2.75s/it]min value is  tensor(-1.0127, device='cuda:0')
#  14% 658/4808 [26:09<4:24:37,  3.83s/it]min value is  tensor(-1.0648, device='cuda:0')
# max value is  tensor(1.0359, device='cuda:0')
#  14% 660/4808 [26:16<4:19:29,  3.75s/it]min value is  tensor(-1.1018, device='cuda:0')
# max value is  tensor(1.1358, device='cuda:0')
#  14% 662/4808 [26:20<2:59:53,  2.60s/it]min value is  tensor(-1.0862, device='cuda:0')
#  14% 664/4808 [26:24<2:40:30,  2.32s/it]max value is  tensor(1.1038, device='cuda:0')
#  14% 666/4808 [26:34<4:06:55,  3.58s/it]min value is  tensor(-1.0260, device='cuda:0')
#  14% 668/4808 [26:41<4:24:03,  3.83s/it]min value is  tensor(-1.0404, device='cuda:0')
# max value is  tensor(1.0299, device='cuda:0')
#  14% 669/4808 [26:48<5:13:42,  4.55s/it]min value is  tensor(-1.0394, device='cuda:0')
#  14% 670/4808 [26:52<5:13:25,  4.54s/it]min value is  tensor(-1.0491, device='cuda:0')
#  14% 671/4808 [26:56<4:47:58,  4.18s/it]min value is  tensor(-1.0006, device='cuda:0')
#  14% 673/4808 [27:01<4:02:02,  3.51s/it]min value is  tensor(-1.0184, device='cuda:0')
# max value is  tensor(1.0016, device='cuda:0')
#  14% 675/4808 [27:06<3:28:31,  3.03s/it]max value is  tensor(1.0271, device='cuda:0')
#  14% 676/4808 [27:08<3:05:08,  2.69s/it]min value is  tensor(-1.0609, device='cuda:0')
# max value is  tensor(1.0924, device='cuda:0')
#  14% 677/4808 [27:12<3:29:14,  3.04s/it]min value is  tensor(-1.0496, device='cuda:0')
# max value is  tensor(1.1202, device='cuda:0')
#  14% 678/4808 [27:14<3:17:32,  2.87s/it]min value is  tensor(-1.0540, device='cuda:0')
# max value is  tensor(1.0611, device='cuda:0')
#  14% 679/4808 [27:15<2:39:39,  2.32s/it]min value is  tensor(-1.0323, device='cuda:0')
# max value is  tensor(1.0983, device='cuda:0')
#  14% 680/4808 [27:18<2:39:26,  2.32s/it]min value is  tensor(-1.0595, device='cuda:0')
# max value is  tensor(1.0371, device='cuda:0')
#  14% 681/4808 [27:20<2:48:23,  2.45s/it]min value is  tensor(-1.1049, device='cuda:0')
# max value is  tensor(1.0701, device='cuda:0')
#  14% 683/4808 [27:24<2:25:06,  2.11s/it]max value is  tensor(1.0243, device='cuda:0')
#  14% 684/4808 [27:26<2:19:33,  2.03s/it]min value is  tensor(-1.0158, device='cuda:0')
#  14% 685/4808 [27:30<2:56:07,  2.56s/it]min value is  tensor(-1.0688, device='cuda:0')
#  14% 687/4808 [27:34<2:29:44,  2.18s/it]max value is  tensor(1.0166, device='cuda:0')
#  14% 689/4808 [27:36<1:51:54,  1.63s/it]min value is  tensor(-1.0117, device='cuda:0')
#  14% 690/4808 [27:38<1:55:36,  1.68s/it]min value is  tensor(-1.0878, device='cuda:0')
# max value is  tensor(1.1092, device='cuda:0')
#  14% 691/4808 [27:40<1:58:40,  1.73s/it]min value is  tensor(-1.0238, device='cuda:0')
# max value is  tensor(1.0267, device='cuda:0')
#  14% 692/4808 [27:41<1:43:24,  1.51s/it]min value is  tensor(-1.0470, device='cuda:0')
# max value is  tensor(1.0122, device='cuda:0')
#  14% 694/4808 [27:44<1:43:40,  1.51s/it]min value is  tensor(-1.1235, device='cuda:0')
#  14% 695/4808 [27:48<2:45:58,  2.42s/it]min value is  tensor(-1.0594, device='cuda:0')
# max value is  tensor(1.0147, device='cuda:0')
#  14% 696/4808 [27:51<2:57:17,  2.59s/it]min value is  tensor(-1.0337, device='cuda:0')
#  14% 697/4808 [27:53<2:37:15,  2.30s/it]min value is  tensor(-1.0143, device='cuda:0')
#  15% 701/4808 [28:02<2:23:52,  2.10s/it]min value is  tensor(-1.0176, device='cuda:0')
#  15% 703/4808 [28:08<2:40:47,  2.35s/it]max value is  tensor(1.0524, device='cuda:0')
#  15% 704/4808 [28:14<3:37:49,  3.18s/it]min value is  tensor(-1.0391, device='cuda:0')
#  15% 705/4808 [28:16<3:24:22,  2.99s/it]max value is  tensor(1.0229, device='cuda:0')
#  15% 706/4808 [28:20<3:42:56,  3.26s/it]min value is  tensor(-1.0097, device='cuda:0')
# max value is  tensor(1.0653, device='cuda:0')
#  15% 708/4808 [28:25<3:21:04,  2.94s/it]min value is  tensor(-1.1023, device='cuda:0')
# max value is  tensor(1.0381, device='cuda:0')
#  15% 709/4808 [28:29<3:44:07,  3.28s/it]max value is  tensor(1.0818, device='cuda:0')
#  15% 710/4808 [28:30<3:07:06,  2.74s/it]max value is  tensor(1.0586, device='cuda:0')
#  15% 712/4808 [28:35<2:54:40,  2.56s/it]max value is  tensor(1.0321, device='cuda:0')
#  15% 714/4808 [28:38<2:20:45,  2.06s/it]min value is  tensor(-1.0742, device='cuda:0')
#  15% 715/4808 [28:42<2:47:52,  2.46s/it]min value is  tensor(-1.0114, device='cuda:0')
# max value is  tensor(1.0565, device='cuda:0')
#  15% 716/4808 [28:44<2:50:15,  2.50s/it]min value is  tensor(-1.0406, device='cuda:0')
# max value is  tensor(1.0248, device='cuda:0')
#  15% 717/4808 [28:46<2:35:02,  2.27s/it]min value is  tensor(-1.0342, device='cuda:0')
# max value is  tensor(1.0052, device='cuda:0')
#  15% 718/4808 [28:49<2:50:58,  2.51s/it]min value is  tensor(-1.0524, device='cuda:0')
# max value is  tensor(1.0300, device='cuda:0')
#  15% 719/4808 [28:50<2:22:39,  2.09s/it]min value is  tensor(-1.0024, device='cuda:0')
#  15% 720/4808 [28:53<2:24:53,  2.13s/it]min value is  tensor(-1.0632, device='cuda:0')
# max value is  tensor(1.0039, device='cuda:0')
#  15% 721/4808 [28:56<2:56:56,  2.60s/it]min value is  tensor(-1.0811, device='cuda:0')
# max value is  tensor(1.1413, device='cuda:0')
#  15% 722/4808 [28:59<2:52:12,  2.53s/it]min value is  tensor(-1.0536, device='cuda:0')
#  15% 723/4808 [29:00<2:33:11,  2.25s/it]min value is  tensor(-1.0048, device='cuda:0')
#  15% 724/4808 [29:03<2:36:57,  2.31s/it]min value is  tensor(-1.0085, device='cuda:0')
#  15% 726/4808 [29:06<2:25:09,  2.13s/it]max value is  tensor(1.0128, device='cuda:0')
#  15% 727/4808 [29:09<2:37:19,  2.31s/it]max value is  tensor(1.0518, device='cuda:0')
#  15% 728/4808 [29:12<2:49:33,  2.49s/it]min value is  tensor(-1.0110, device='cuda:0')
#  15% 729/4808 [29:14<2:47:09,  2.46s/it]max value is  tensor(1.0010, device='cuda:0')
#  15% 730/4808 [29:17<2:50:38,  2.51s/it]min value is  tensor(-1.0115, device='cuda:0')
#  15% 731/4808 [29:19<2:48:27,  2.48s/it]min value is  tensor(-1.0172, device='cuda:0')
# max value is  tensor(1.0634, device='cuda:0')
#  15% 732/4808 [29:22<2:58:25,  2.63s/it]min value is  tensor(-1.0082, device='cuda:0')
# max value is  tensor(1.0538, device='cuda:0')
#  15% 733/4808 [29:26<3:07:59,  2.77s/it]min value is  tensor(-1.0579, device='cuda:0')
#  15% 745/4808 [29:56<2:21:22,  2.09s/it]min value is  tensor(-1.1101, device='cuda:0')
# max value is  tensor(1.0725, device='cuda:0')
#  16% 746/4808 [29:59<2:36:23,  2.31s/it]min value is  tensor(-1.0796, device='cuda:0')
#  16% 747/4808 [30:02<2:48:11,  2.49s/it]min value is  tensor(-1.0187, device='cuda:0')
# max value is  tensor(1.0662, device='cuda:0')
#  16% 749/4808 [30:05<2:12:38,  1.96s/it]min value is  tensor(-1.0256, device='cuda:0')
# max value is  tensor(1.0444, device='cuda:0')
#  16% 750/4808 [30:07<2:14:09,  1.98s/it]min value is  tensor(-1.0174, device='cuda:0')
# max value is  tensor(1.1059, device='cuda:0')
#  16% 751/4808 [30:09<2:32:26,  2.25s/it]min value is  tensor(-1.0517, device='cuda:0')
# ...
#  80% 3839/4808 [2:28:59<17:08,  1.06s/it]min value is  tensor(-1.0578, device='cuda:0')
#  80% 3841/4808 [2:29:02<22:16,  1.38s/it]min value is  tensor(-1.0084, device='cuda:0')
#  80% 3843/4808 [2:29:05<23:38,  1.47s/it]min value is  tensor(-1.0022, device='cuda:0')
#  80% 3848/4808 [2:29:11<20:54,  1.31s/it]max value is  tensor(1.0027, device='cuda:0')
#  80% 3854/4808 [2:29:17<14:14,  1.12it/s]min value is  tensor(-1.0004, device='cuda:0')
#  80% 3855/4808 [2:29:18<15:49,  1.00it/s]max value is  tensor(1.0129, device='cuda:0')
#  80% 3856/4808 [2:29:19<17:41,  1.12s/it]min value is  tensor(-1.0014, device='cuda:0')
#  80% 3860/4808 [2:29:27<29:50,  1.89s/it]max value is  tensor(1.0586, device='cuda:0')
#  80% 3861/4808 [2:29:28<24:48,  1.57s/it]max value is  tensor(1.0388, device='cuda:0')
#  80% 3865/4808 [2:29:38<34:48,  2.21s/it]max value is  tensor(1.0335, device='cuda:0')
#  80% 3866/4808 [2:29:41<36:06,  2.30s/it]min value is  tensor(-1.0134, device='cuda:0')
#  80% 3870/4808 [2:29:48<31:13,  2.00s/it]min value is  tensor(-1.0184, device='cuda:0')
# max value is  tensor(1.0506, device='cuda:0')
#  81% 3875/4808 [2:29:55<25:48,  1.66s/it]min value is  tensor(-1.0018, device='cuda:0')
# max value is  tensor(1.0103, device='cuda:0')
#  81% 3876/4808 [2:29:57<28:35,  1.84s/it]max value is  tensor(1.0241, device='cuda:0')
#  81% 3883/4808 [2:30:11<31:54,  2.07s/it]min value is  tensor(-1.0161, device='cuda:0')
#  81% 3887/4808 [2:30:20<32:39,  2.13s/it]max value is  tensor(1.0126, device='cuda:0')
#  81% 3900/4808 [2:30:51<36:37,  2.42s/it]min value is  tensor(-1.0049, device='cuda:0')
# max value is  tensor(1.0012, device='cuda:0')
#  81% 3909/4808 [2:31:12<33:24,  2.23s/it]min value is  tensor(-1.0051, device='cuda:0')
# max value is  tensor(1.0286, device='cuda:0')
#  82% 3920/4808 [2:31:34<25:35,  1.73s/it]min value is  tensor(-1.0009, device='cuda:0')
#  82% 3924/4808 [2:31:39<23:11,  1.57s/it]max value is  tensor(1.0080, device='cuda:0')
#  82% 3936/4808 [2:31:58<24:49,  1.71s/it]min value is  tensor(-1.1070, device='cuda:0')
#  82% 3941/4808 [2:32:06<24:36,  1.70s/it]min value is  tensor(-1.0154, device='cuda:0')
#  82% 3955/4808 [2:32:33<23:54,  1.68s/it]min value is  tensor(-1.0165, device='cuda:0')
#  83% 3967/4808 [2:32:53<30:10,  2.15s/it]min value is  tensor(-1.0258, device='cuda:0')
#  83% 3971/4808 [2:33:03<33:57,  2.43s/it]min value is  tensor(-1.0170, device='cuda:0')
#  83% 3975/4808 [2:33:13<33:56,  2.44s/it]min value is  tensor(-1.0275, device='cuda:0')
#  83% 3995/4808 [2:33:51<23:02,  1.70s/it]min value is  tensor(-1.0011, device='cuda:0')
#  83% 4000/4808 [2:34:07<38:18,  2.84s/it]min value is  tensor(-1.0190, device='cuda:0')
# max value is  tensor(1.0033, device='cuda:0')
#  84% 4020/4808 [2:34:41<18:51,  1.44s/it]min value is  tensor(-1.0247, device='cuda:0')
# max value is  tensor(1.0073, device='cuda:0')
#  84% 4034/4808 [2:35:22<29:05,  2.26s/it]min value is  tensor(-1.0834, device='cuda:0')
#  84% 4038/4808 [2:35:28<25:32,  1.99s/it]min value is  tensor(-1.0016, device='cuda:0')
#  84% 4041/4808 [2:35:37<33:22,  2.61s/it]max value is  tensor(1.0002, device='cuda:0')
#  84% 4044/4808 [2:35:43<24:22,  1.91s/it]max value is  tensor(1.0135, device='cuda:0')
#  84% 4049/4808 [2:35:49<14:09,  1.12s/it]min value is  tensor(-1.0039, device='cuda:0')
# max value is  tensor(1.0144, device='cuda:0')
#  84% 4051/4808 [2:35:54<20:38,  1.64s/it]min value is  tensor(-1.0153, device='cuda:0')
#  84% 4056/4808 [2:36:06<29:27,  2.35s/it]max value is  tensor(1.0010, device='cuda:0')
#  84% 4060/4808 [2:36:17<30:20,  2.43s/it]min value is  tensor(-1.0504, device='cuda:0')
#  85% 4063/4808 [2:36:24<28:26,  2.29s/it]min value is  tensor(-1.0371, device='cuda:0')
# max value is  tensor(1.0050, device='cuda:0')
#  85% 4067/4808 [2:36:34<26:29,  2.15s/it]min value is  tensor(-1.0099, device='cuda:0')
#  85% 4071/4808 [2:36:46<27:37,  2.25s/it]max value is  tensor(1.0015, device='cuda:0')
#  85% 4076/4808 [2:36:54<17:38,  1.45s/it]max value is  tensor(1.0068, device='cuda:0')
#  85% 4092/4808 [2:37:24<29:04,  2.44s/it]min value is  tensor(-1.0311, device='cuda:0')
#  85% 4095/4808 [2:37:31<24:49,  2.09s/it]min value is  tensor(-1.0129, device='cuda:0')
#  85% 4097/4808 [2:37:36<29:11,  2.46s/it]max value is  tensor(1.0090, device='cuda:0')
#  85% 4106/4808 [2:37:47<14:11,  1.21s/it]min value is  tensor(-1.0253, device='cuda:0')
#  85% 4109/4808 [2:37:54<18:45,  1.61s/it]max value is  tensor(1.0003, device='cuda:0')
#  86% 4112/4808 [2:37:56<11:13,  1.03it/s]min value is  tensor(-1.0116, device='cuda:0')
#  86% 4122/4808 [2:38:04<06:33,  1.74it/s]min value is  tensor(-1.0077, device='cuda:0')
# max value is  tensor(1.0301, device='cuda:0')
#  86% 4125/4808 [2:38:07<08:29,  1.34it/s]max value is  tensor(1.0837, device='cuda:0')
#  86% 4126/4808 [2:38:08<10:06,  1.12it/s]max value is  tensor(1.0076, device='cuda:0')
#  86% 4142/4808 [2:38:28<16:38,  1.50s/it]max value is  tensor(1.0217, device='cuda:0')
#  86% 4147/4808 [2:38:33<12:59,  1.18s/it]min value is  tensor(-1.0274, device='cuda:0')
#  86% 4150/4808 [2:38:36<10:56,  1.00it/s]min value is  tensor(-1.0008, device='cuda:0')
#  86% 4152/4808 [2:38:37<08:30,  1.28it/s]min value is  tensor(-1.0226, device='cuda:0')
# max value is  tensor(1.0186, device='cuda:0')
#  86% 4154/4808 [2:38:41<13:49,  1.27s/it]min value is  tensor(-1.0012, device='cuda:0')
#  87% 4173/4808 [2:39:08<23:21,  2.21s/it]min value is  tensor(-1.0037, device='cuda:0')
# max value is  tensor(1.0118, device='cuda:0')
#  87% 4189/4808 [2:39:34<21:50,  2.12s/it]min value is  tensor(-1.0074, device='cuda:0')
#  87% 4192/4808 [2:39:44<28:14,  2.75s/it]min value is  tensor(-1.1032, device='cuda:0')
#  87% 4193/4808 [2:39:47<28:06,  2.74s/it]min value is  tensor(-1.0075, device='cuda:0')
#  87% 4194/4808 [2:39:49<26:12,  2.56s/it]min value is  tensor(-1.0018, device='cuda:0')
#  87% 4197/4808 [2:39:56<24:01,  2.36s/it]min value is  tensor(-1.0415, device='cuda:0')
#  88% 4208/4808 [2:40:14<18:58,  1.90s/it]min value is  tensor(-1.0175, device='cuda:0')
#  88% 4209/4808 [2:40:15<16:16,  1.63s/it]min value is  tensor(-1.0533, device='cuda:0')
# max value is  tensor(1.0021, device='cuda:0')
#  88% 4210/4808 [2:40:17<17:19,  1.74s/it]max value is  tensor(1.0028, device='cuda:0')
#  88% 4218/4808 [2:40:32<20:18,  2.06s/it]min value is  tensor(-1.0216, device='cuda:0')
#  88% 4223/4808 [2:40:44<25:12,  2.59s/it]min value is  tensor(-1.0106, device='cuda:0')
#  88% 4224/4808 [2:40:46<21:06,  2.17s/it]max value is  tensor(1.0102, device='cuda:0')
#  88% 4225/4808 [2:40:48<21:18,  2.19s/it]max value is  tensor(1.0313, device='cuda:0')
#  88% 4232/4808 [2:41:03<18:59,  1.98s/it]min value is  tensor(-1.0117, device='cuda:0')
#  88% 4234/4808 [2:41:07<20:23,  2.13s/it]min value is  tensor(-1.0026, device='cuda:0')
#  88% 4244/4808 [2:41:30<18:09,  1.93s/it]min value is  tensor(-1.0301, device='cuda:0')
#  88% 4245/4808 [2:41:32<17:15,  1.84s/it]min value is  tensor(-1.0098, device='cuda:0')
#  89% 4256/4808 [2:41:52<16:21,  1.78s/it]max value is  tensor(1.0441, device='cuda:0')
#  89% 4264/4808 [2:42:04<14:03,  1.55s/it]max value is  tensor(1.0020, device='cuda:0')
#  89% 4273/4808 [2:42:19<14:24,  1.62s/it]min value is  tensor(-1.0223, device='cuda:0')
# max value is  tensor(1.0750, device='cuda:0')
#  89% 4288/4808 [2:42:42<13:08,  1.52s/it]max value is  tensor(1.0242, device='cuda:0')
#  89% 4297/4808 [2:42:53<11:45,  1.38s/it]max value is  tensor(1.0013, device='cuda:0')
#  90% 4336/4808 [2:43:55<15:58,  2.03s/it]min value is  tensor(-1.0267, device='cuda:0')
#  90% 4344/4808 [2:44:09<14:06,  1.82s/it]min value is  tensor(-1.0012, device='cuda:0')
#  90% 4349/4808 [2:44:17<10:40,  1.40s/it]max value is  tensor(1.0137, device='cuda:0')
#  91% 4352/4808 [2:44:21<09:49,  1.29s/it]min value is  tensor(-1.0300, device='cuda:0')
#  91% 4353/4808 [2:44:24<13:14,  1.75s/it]min value is  tensor(-1.0010, device='cuda:0')
#  91% 4354/4808 [2:44:26<14:11,  1.88s/it]max value is  tensor(1.0005, device='cuda:0')
#  91% 4355/4808 [2:44:27<13:08,  1.74s/it]min value is  tensor(-1.0311, device='cuda:0')
#  91% 4359/4808 [2:44:34<12:34,  1.68s/it]max value is  tensor(1.0173, device='cuda:0')
#  91% 4361/4808 [2:44:39<15:45,  2.12s/it]min value is  tensor(-1.0099, device='cuda:0')
#  91% 4367/4808 [2:44:48<10:29,  1.43s/it]min value is  tensor(-1.0300, device='cuda:0')
#  91% 4374/4808 [2:45:02<15:05,  2.09s/it]max value is  tensor(1.0151, device='cuda:0')
#  91% 4377/4808 [2:45:06<10:57,  1.53s/it]min value is  tensor(-1.0674, device='cuda:0')
# max value is  tensor(1.0323, device='cuda:0')
#  91% 4381/4808 [2:45:11<08:26,  1.19s/it]min value is  tensor(-1.0193, device='cuda:0')
# max value is  tensor(1.0238, device='cuda:0')
#  91% 4386/4808 [2:45:19<10:11,  1.45s/it]min value is  tensor(-1.1175, device='cuda:0')
# max value is  tensor(1.0424, device='cuda:0')
#  91% 4388/4808 [2:45:24<12:55,  1.85s/it]max value is  tensor(1.0123, device='cuda:0')
#  91% 4389/4808 [2:45:26<12:05,  1.73s/it]min value is  tensor(-1.0006, device='cuda:0')
#  92% 4415/4808 [2:46:26<16:35,  2.53s/it]min value is  tensor(-1.0133, device='cuda:0')
#  92% 4416/4808 [2:46:29<17:22,  2.66s/it]min value is  tensor(-1.0074, device='cuda:0')
#  92% 4422/4808 [2:46:42<12:50,  2.00s/it]min value is  tensor(-1.0232, device='cuda:0')
#  92% 4423/4808 [2:46:44<12:42,  1.98s/it]min value is  tensor(-1.1017, device='cuda:0')
# max value is  tensor(1.0037, device='cuda:0')
#  92% 4426/4808 [2:46:48<10:40,  1.68s/it]min value is  tensor(-1.0077, device='cuda:0')
#  92% 4433/4808 [2:47:05<13:37,  2.18s/it]min value is  tensor(-1.0618, device='cuda:0')
#  92% 4442/4808 [2:47:26<13:21,  2.19s/it]max value is  tensor(1.0004, device='cuda:0')
#  93% 4450/4808 [2:47:40<11:04,  1.86s/it]max value is  tensor(1.0092, device='cuda:0')
#  93% 4451/4808 [2:47:43<12:27,  2.09s/it]min value is  tensor(-1.0276, device='cuda:0')
#  93% 4473/4808 [2:48:26<10:48,  1.93s/it]max value is  tensor(1.0184, device='cuda:0')
#  93% 4487/4808 [2:48:57<11:29,  2.15s/it]max value is  tensor(1.0009, device='cuda:0')
#  93% 4493/4808 [2:49:08<07:41,  1.46s/it]min value is  tensor(-1.0275, device='cuda:0')
#  94% 4499/4808 [2:49:21<10:28,  2.03s/it]max value is  tensor(1.0158, device='cuda:0')
#  94% 4500/4808 [2:49:24<10:33,  2.06s/it]max value is  tensor(1.0029, device='cuda:0')
#  94% 4508/4808 [2:49:37<08:02,  1.61s/it]min value is  tensor(-1.0040, device='cuda:0')
# max value is  tensor(1.0291, device='cuda:0')
#  94% 4524/4808 [2:50:06<07:53,  1.67s/it]max value is  tensor(1.0486, device='cuda:0')
#  94% 4533/4808 [2:50:22<08:24,  1.83s/it]max value is  tensor(1.0556, device='cuda:0')
#  94% 4534/4808 [2:50:23<07:58,  1.75s/it]max value is  tensor(1.0023, device='cuda:0')
#  94% 4540/4808 [2:50:32<06:53,  1.54s/it]max value is  tensor(1.0006, device='cuda:0')
#  95% 4544/4808 [2:50:37<05:30,  1.25s/it]max value is  tensor(1.0163, device='cuda:0')
#  95% 4545/4808 [2:50:39<05:54,  1.35s/it]max value is  tensor(1.0326, device='cuda:0')
#  95% 4549/4808 [2:50:43<05:19,  1.23s/it]min value is  tensor(-1.0111, device='cuda:0')
# max value is  tensor(1.1062, device='cuda:0')
#  95% 4554/4808 [2:50:53<07:54,  1.87s/it]max value is  tensor(1.0717, device='cuda:0')
#  95% 4563/4808 [2:51:07<04:45,  1.17s/it]min value is  tensor(-1.0156, device='cuda:0')
# max value is  tensor(1.0171, device='cuda:0')
#  95% 4583/4808 [2:51:38<05:37,  1.50s/it]min value is  tensor(-1.0374, device='cuda:0')
#  95% 4584/4808 [2:51:39<05:28,  1.47s/it]min value is  tensor(-1.0152, device='cuda:0')
#  96% 4603/4808 [2:52:04<02:26,  1.40it/s]max value is  tensor(1.0248, device='cuda:0')
#  96% 4605/4808 [2:52:05<01:58,  1.72it/s]min value is  tensor(-1.0003, device='cuda:0')
# max value is  tensor(1.0043, device='cuda:0')
#  96% 4606/4808 [2:52:09<04:52,  1.45s/it]min value is  tensor(-1.0251, device='cuda:0')
#  96% 4610/4808 [2:52:17<05:46,  1.75s/it]max value is  tensor(1.0318, device='cuda:0')
#  96% 4612/4808 [2:52:19<04:06,  1.26s/it]min value is  tensor(-1.0810, device='cuda:0')
#  96% 4615/4808 [2:52:23<04:22,  1.36s/it]max value is  tensor(1.0246, device='cuda:0')
#  96% 4622/4808 [2:52:34<05:58,  1.93s/it]min value is  tensor(-1.0099, device='cuda:0')
# max value is  tensor(1.0219, device='cuda:0')
#  96% 4623/4808 [2:52:36<05:44,  1.86s/it]min value is  tensor(-1.0272, device='cuda:0')
# max value is  tensor(1.0056, device='cuda:0')
#  96% 4624/4808 [2:52:40<07:09,  2.33s/it]max value is  tensor(1.0180, device='cuda:0')
#  96% 4625/4808 [2:52:41<06:13,  2.04s/it]max value is  tensor(1.0127, device='cuda:0')
#  96% 4628/4808 [2:52:46<05:20,  1.78s/it]min value is  tensor(-1.0032, device='cuda:0')
#  96% 4630/4808 [2:52:50<05:29,  1.85s/it]max value is  tensor(1.0493, device='cuda:0')
#  96% 4636/4808 [2:53:04<04:38,  1.62s/it]max value is  tensor(1.0478, device='cuda:0')
#  96% 4639/4808 [2:53:08<04:12,  1.49s/it]min value is  tensor(-1.0057, device='cuda:0')
#  97% 4648/4808 [2:53:14<01:58,  1.35it/s]max value is  tensor(1.0203, device='cuda:0')
#  97% 4652/4808 [2:53:20<03:25,  1.32s/it]min value is  tensor(-1.0426, device='cuda:0')
# max value is  tensor(1.0355, device='cuda:0')
#  97% 4658/4808 [2:53:32<03:27,  1.38s/it]max value is  tensor(1.0280, device='cuda:0')
#  97% 4663/4808 [2:53:44<04:53,  2.02s/it]min value is  tensor(-1.0159, device='cuda:0')
#  97% 4664/4808 [2:53:46<04:30,  1.88s/it]min value is  tensor(-1.0038, device='cuda:0')
#  97% 4687/4808 [2:54:44<04:22,  2.17s/it]max value is  tensor(1.0944, device='cuda:0')
#  98% 4688/4808 [2:54:46<04:03,  2.03s/it]min value is  tensor(-1.0377, device='cuda:0')
#  98% 4696/4808 [2:55:01<03:25,  1.83s/it]min value is  tensor(-1.0303, device='cuda:0')
#  98% 4704/4808 [2:55:11<01:45,  1.01s/it]max value is  tensor(1.0073, device='cuda:0')
#  98% 4710/4808 [2:55:18<01:58,  1.21s/it]min value is  tensor(-1.0141, device='cuda:0')
#  98% 4714/4808 [2:55:25<02:22,  1.51s/it]min value is  tensor(-1.0073, device='cuda:0')
#  98% 4719/4808 [2:55:35<02:29,  1.67s/it]max value is  tensor(1.0036, device='cuda:0')
#  98% 4722/4808 [2:55:41<02:36,  1.82s/it]max value is  tensor(1.0012, device='cuda:0')
#  98% 4735/4808 [2:55:58<01:40,  1.38s/it]min value is  tensor(-1.0053, device='cuda:0')
#  99% 4738/4808 [2:56:04<02:13,  1.91s/it]max value is  tensor(1.0394, device='cuda:0')
#  99% 4739/4808 [2:56:06<02:09,  1.88s/it]max value is  tensor(1.0688, device='cuda:0')
#  99% 4747/4808 [2:56:18<01:51,  1.82s/it]min value is  tensor(-1.0126, device='cuda:0')
#  99% 4758/4808 [2:56:42<01:30,  1.81s/it]min value is  tensor(-1.0159, device='cuda:0')
# max value is  tensor(1.0491, device='cuda:0')
#  99% 4760/4808 [2:56:46<01:20,  1.69s/it]max value is  tensor(1.0202, device='cuda:0')
#  99% 4767/4808 [2:56:57<01:09,  1.69s/it]min value is  tensor(-1.0435, device='cuda:0')
#  99% 4779/4808 [2:57:16<00:47,  1.63s/it]min value is  tensor(-1.0514, device='cuda:0')
# 100% 4784/4808 [2:57:21<00:23,  1.02it/s]min value is  tensor(-1.0765, device='cuda:0')
# max value is  tensor(1.0735, device='cuda:0')
# 100% 4787/4808 [2:57:26<00:30,  1.44s/it]min value is  tensor(-1.0054, device='cuda:0')
# max value is  tensor(1.0299, device='cuda:0')
# 100% 4788/4808 [2:57:28<00:32,  1.60s/it]min value is  tensor(-1.0127, device='cuda:0')
# max value is  tensor(1.0116, device='cuda:0')
# 100% 4789/4808 [2:57:29<00:28,  1.49s/it]min value is  tensor(-1.0072, device='cuda:0')
# max value is  tensor(1.0136, device='cuda:0')
# 100% 4790/4808 [2:57:30<00:23,  1.30s/it]min value is  tensor(-1.0122, device='cuda:0')
# max value is  tensor(1.0341, device='cuda:0')
# 100% 4793/4808 [2:57:34<00:18,  1.21s/it]max value is  tensor(1.0270, device='cuda:0')
# 100% 4798/4808 [2:57:40<00:10,  1.07s/it]max value is  tensor(1.0292, device='cuda:0')
# 100% 4802/4808 [2:57:45<00:06,  1.15s/it]min value is  tensor(-1.0078, device='cuda:0')
# 100% 4805/4808 [2:57:51<00:04,  1.43s/it]max value is  tensor(1.0102, device='cuda:0')
# 100% 4808/4808 [2:57:57<00:00,  2.22s/it]
# (128,)
# | train total duration: 27027.982s
# /content/diff-svc/data
# copied '/content/Altoria_binary_data.7z' -> '/content/drive/MyDrive/diff-svc/data/Altoria/Altoria_binary_data.7z'
# removed '/content/Altoria_binary_data.7z'

# %%
#@title #Step 5-0 Tensorboard (run before step 5)
#@markdown Shows training progress, go to the top right corner to set it to update the logs.

import datetime, os

if use_save_dir:
  # %tensorboard --load_fast=true --reload_interval=1 --reload_multifile=true --logdir="{save_dir}/lightning_logs/"
else:
  # %tensorboard --load_fast=true --reload_interval=1 --reload_multifile=true --logdir=/content/diff-svc/checkpoints/{singer_name}/lightning_logs/

# %%
#@title #Step 5: Training
#@markdown Yeah, it took THAT long to get here, colab is probably going to disconnect you at this point... unless you have pro ¯\\_(ツ)_/¯
# %cd "/content/diff-svc/"

os.environ['PYTHONPATH']='.'

# !CUDA_VISIBLE_DEVICES=0 python run.py --config {config_path} --exp_name $singer_name --reset

# %%
#@title # Step 6: Package Model
#@markdown If you used a custom directory for saving your models please don't use this.

store_on_drive = True #@param {type: "boolean"}
from datetime import datetime, timezone
import glob

time_now = datetime.now(timezone.utc).strftime('%Y-%m-%d %H-%M-%S')

archive_name = f'{singer_name}_{time_now}'

if use_save_dir:
  # %cd {save_dir}
  # !zip -r "/content/{archive_name}.zip" ./ -x ./lighting_logs/\*
else:
  # %cd /content/diff-svc/checkpoints
  # !zip -r "/content/{archive_name}.zip" ./{singer_name} -x ./{singer_name}/lighting_logs/\*

if store_on_drive:
      if not os.path.exists('/content/drive/MyDrive/Diff-SVC_release'):
          # !mkdir /content/drive/MyDrive/Diff-SVC_release
      
      # !mv -v "/content/{archive_name}.zip" /content/drive/MyDrive/Diff-SVC_release

print('Done!')
